# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/drive/1mI09153HhqUe-uZ4DXDo1NH3vntbr8oQ)

# %% [markdown]
# ⚕️Estomatologia - Lesões Ulceradas Crônicas⚕️

# %%
import textwrap
import shutil

margem = 2
largura_terminal = 50
largura_util = largura_terminal - 2 * margem

texto = "Texto centralizado com margens."
linhas = textwrap.wrap(texto, width=largura_util)
for linha in linhas:
    print(" " * margem + linha.center(largura_util) + " " * margem)

def diagnostico_lesoes_ulceradas_cronicas():
    """
    Função para diagnóstico de lesões ulceradas crônicas na mucosa bucal

    """

    print("🎯 Diagnóstico de Lesões Ulceradas Crônicas na Mucosa Bucal 🎯\n")

    # Passo 1: Histórico de trauma ou fator irritativo
    trauma = input("🤕 Houve trauma ou outro fator irritativo associado? (sim/nao): ").lower()
    if trauma == "sim":
        print("\n➡️  Diagnóstico provável: ÚLCERA TRAUMÁTICA CRÔNICA")
        print("     - 💥 **Definição e Etiologia:** Lesão causada por trauma de baixa intensidade e longa duração. Exemplos: dente com aresta cortante, prótese mal adaptada, mordiscamento crônico.")
        print("     - 🔴 **Aspecto Clínico:** Úlcera de tamanho variável, geralmente com bordas elevadas e endurecidas (devido à infiltração de células inflamatórias e/ou tecido de granulação). Pode apresentar dor, mas a intensidade costuma ser menor do que nas úlceras traumáticas agudas. A localização varia de acordo com o agente causal.")
        print("     - 🔬 **Como Estabelecer o Diagnóstico:** História de trauma crônico, exame clínico, e, principalmente, a melhora ou resolução da lesão após a remoção do fator irritativo (em cerca de 7-14 dias). Biópsia pode ser necessária se não houver regressão ou se houver dúvida diagnóstica.")
        print("     - 🩹 **Conduta:** Remoção do agente causador (ex.: ajuste oclusal, polimento de arestas cortantes, ajuste ou confecção de nova prótese). Analgésicos tópicos (ex.: Omcilon-A em orabase) ou bochechos com solução de clorexidina 0,12% podem ser utilizados para alívio da dor e prevenção de infecção secundária. Acompanhar a evolução da lesão. Se não houver melhora em 7-14 dias, considerar biópsia.\n")

        sialo = input("👄 A lesão está localizada em palato e houve procedimento odontológico com anestesia local na região recentemente? (sim/nao): ").lower()
        if sialo == "sim":
          print("\n➡️  Diagnóstico provável: SIALOMETAPLASIA NECROTIZANTE")
          print("     - 💉 **Definição e Etiologia:** Condição inflamatória que leva à necrose das glândulas salivares menores. Fatores predisponentes: trauma local, injeção de anestésicos locais, cirurgias prévias, próteses mal adaptadas.")
          print("     - 🔴 **Aspecto Clínico:** Mais comum em palato. Inicialmente, apresenta-se como uma tumefação dolorosa, seguida por necrose tecidual e formação de uma úlcera profunda em formato de cratera. Pode haver necrose do osso subjacente. A dor pode diminuir após a formação da úlcera.")
          print("     - 🔬 **Como Estabelecer o Diagnóstico:** História clínica (procedimento odontológico recente em palato), aspecto clínico da lesão e, se necessário, biópsia incisional. A biópsia é importante para descartar malignidade, pois a sialometaplasia necrotizante pode se assemelhar a um carcinoma.")
          print("     - 🩹 **Conduta:** Acompanhamento clínico. A lesão geralmente cicatriza espontaneamente em 5-6 semanas. Se não houver melhora em 1-2 semanas, realizar biópsia incisional. Analgésicos podem ser prescritos para controle da dor.\n")

    else:
        # Passo 2: Histórico de recorrência
        recorrencia = input("🔁 A lesão tem histórico de recorrência (aparece e desaparece)? (sim/nao): ").lower()
        if recorrencia == "sim":
            duracao = input("⏳ Quando a lesão aparece, ela tem uma duração curta (dias) ou longa (semanas)? (curta/longa): ").lower()
            if duracao == "curta":
              mucosa_ceratinizada = input("👅 A lesão aparece em mucosa ceratinizada (gengiva inserida e palato duro)? (sim/nao): ").lower()
              if mucosa_ceratinizada == 'nao':
                print("\n➡️  Diagnóstico provável: ULCERAÇÃO AFTOSA RECORRENTE (UAR)")
                print("     - ❓ **Definição e Etiologia:** Condição idiopática (causa desconhecida) caracterizada por úlceras recorrentes em mucosa bucal não ceratinizada. Fatores predisponentes: estresse, alergias, deficiências nutricionais, trauma, predisposição genética.")
                print("     - 🔴 **Aspecto Clínico:** Três formas: UAR menor (mais comum, úlceras rasas e pequenas, 0,3-1 cm, em mucosa não ceratinizada), UAR maior (úlceras maiores, 1-3 cm, mais profundas, podem deixar cicatrizes) e UAR herpetiforme (múltiplas úlceras pequenas, 1-3 mm, podem coalescer). Dor é um sintoma comum. As lesões podem ser precedidas por máculas eritematosas com sensação de queimação ou prurido.")
                print("     - 🔬 **Como Estabelecer o Diagnóstico:** Clínico, baseado na recorrência das lesões, aspecto clínico, localização em mucosa não ceratinizada e exclusão de outras hipóteses. Avaliação médica para descartar condições sistêmicas associadas (ex.: doença de Behçet, doenças inflamatórias intestinais).")
                print("     - 🩹 **Conduta:** Tratamento paliativo, visando reduzir a dor e o tempo de cicatrização. Analgésicos tópicos (ex.: Ad-Muc), bochechos com corticosteroides (ex.: dexametasona elixir). Em casos severos, corticosteroides sistêmicos podem ser necessários. Identificar e, se possível, eliminar fatores desencadeantes.\n")
              else:
                print("\n➡️  Diagnóstico provável: HERPES SECUNDÁRIO (RECORRENTE)")
                print("     - 🦠 **Definição e Etiologia:** Reativação do vírus herpes simples (HSV) latente no gânglio trigêmeo. Fatores desencadeantes: exposição solar, estresse, imunossupressão, trauma.")
                print("     - 🔴 **Aspecto Clínico:** Pródromo: queimação, dormência ou prurido na área afetada. Lesões vesiculares que coalescem e se rompem, formando úlceras. Preferencialmente na região perilabial (transição entre pele e vermelhão do lábio) ou em mucosa ceratinizada intraoral (gengiva inserida e palato duro). Crostas podem se formar sobre as úlceras.")
                print("     - 🔬 **Como Estabelecer o Diagnóstico:** Clínico, baseado na recorrência, localização das lesões (lábio, mucosa ceratinizada), sintomas prodrômicos e aspecto clínico. Exames laboratoriais (cultura viral, PCR) podem ser realizados, mas nem sempre são necessários.")
                print("     - 🩹 **Conduta:** Antivirais tópicos (ex.: aciclovir creme) ou sistêmicos (ex.: aciclovir, valaciclovir) são mais eficazes se administrados no período prodrômico ou na fase inicial das lesões. Analgésicos tópicos ou sistêmicos para alívio da dor. Laserterapia de baixa intensidade pode acelerar a cicatrização. Orientar o paciente sobre a natureza contagiosa das lesões, principalmente na fase de vesículas.\n")

            else: # Duração longa
                print("\n➡️  Possíveis diagnósticos com lesões de longa duração e histórico de recorrência (baseado em características adicionais):")

                liquen = input("👄 A lesão tem predominância de lesões brancas, com erosões/úlceras eventuais, principalmente em mucosa jugal? (sim/nao): ").lower()
                if liquen == "sim":
                    print("\n➡️  Diagnóstico provável: LÍQUEN PLANO EROSIVO")
                    print("     - 🤔 **Definição e Etiologia:** Doença mucocutânea inflamatória crônica, de causa desconhecida. Acredita-se que seja uma doença autoimune mediada por linfócitos T.")
                    print("     - ⚪/🔴 **Aspecto Clínico:**  Forma reticular (linhas brancas entrelaçadas - estrias de Wickham) e forma erosiva (áreas eritematosas atróficas com graus variados de ulceração central, circundadas por estrias brancas). A forma erosiva causa dor e queimação. Localizações mais comuns: mucosa jugal, língua e gengiva. Gengivite descamativa pode ser uma manifestação. Pode haver períodos de remissão e exacerbação, muitas vezes associados a estresse.")
                    print("     - 🔬 **Como Estabelecer o Diagnóstico:**  Aspecto clínico, histórico de recorrência. Biópsia incisional é fundamental para confirmar o diagnóstico e descartar displasia/malignidade. Imunofluorescência direta pode ser necessária em casos atípicos.")
                    print("     - 🩹 **Conduta:** Corticosteroides tópicos (ex.: clobetasol gel, dexametasona elixir) para controle dos sintomas e das lesões erosivas/atróficas. Em casos de gengivite descamativa, pode-se usar moldeiras de acetato para aplicação do corticosteroide tópico. Casos refratários podem necessitar de corticosteroides sistêmicos, prescritos por estomatologista ou dermatologista. Acompanhamento regular devido ao potencial (baixo) de malignização.\n")

                penfigo = input("👄 Há predomínio de erosões e úlceras, com história de bolhas que se rompem facilmente? (sim/nao): ").lower()
                if penfigo == "sim":
                  print("\n➡️ Diagnóstico provável: PÊNFIGO VULGAR")
                  print("     - 🤔 **Definição e Etiologia:** Doença autoimune bolhosa mucocutânea, potencialmente fatal. Autoanticorpos contra proteínas das junções intercelulares dos queratinócitos (desmogleína 3 e/ou 1), levando à acantólise (perda de adesão entre as células epiteliais).")
                  print("     - 🔴 **Aspecto Clínico:** Bolhas intraepiteliais frágeis que se rompem facilmente, deixando áreas erosadas e ulceradas dolorosas. Pode afetar qualquer área da mucosa bucal, sendo mais comum em lábio, palato, ventre lingual e gengiva. Sinal de Nikolsky (formação de bolha após pressão lateral em pele ou mucosa aparentemente normal) pode ser positivo. Lesões cutâneas podem surgir meses após as lesões bucais.")
                  print("     - 🔬 **Como Estabelecer o Diagnóstico:**  Suspeita clínica (bolhas que se rompem facilmente, áreas extensas de erosão/ulceração). Biópsia incisional (incluindo área perilesional) para exame histopatológico e imunofluorescência direta (padrão em “favo de mel”).")
                  print("     - 💊 **Conduta:** Encaminhamento para dermatologista/estomatologista experiente em doenças bolhosas. Tratamento com corticosteroides sistêmicos e imunossupressores. Prognóstico reservado, dependendo da extensão e gravidade da doença. Acompanhamento rigoroso.\n")

                penfigoide = input("👄 Além das lesões na boca, há envolvimento ocular, com possível formação de aderências entre a pálpebra e o globo ocular? (sim/nao): ").lower()
                if penfigoide == 'sim':
                    print("\n➡️ Diagnóstico provável: PENFIGÓIDE CICATRICIAL (OU PENFIGÓIDE BENIGNO DAS MEMBRANAS MUCOSAS)")
                    print("     - 🤔 **Definição e Etiologia:** Doença autoimune bolhosa mucocutânea crônica. Autoanticorpos contra componentes da membrana basal, levando à formação de bolhas subepiteliais.")
                    print("     - 🔴 **Aspecto Clínico:** Bolhas mais tensas e duradouras do que no pênfigo vulgar. Após o rompimento, formam-se úlceras que podem cicatrizar. Acomete principalmente mucosa bucal (gengiva - gengivite descamativa), ocular (simbléfaro - aderência entre a pálpebra e o globo ocular), nasal, laríngea e pele. Dor e queimação são sintomas comuns.")
                    print("     - 🔬 **Como Estabelecer o Diagnóstico:**  Suspeita clínica (bolhas, úlceras, envolvimento ocular). Biópsia incisional (incluindo área perilesional) para exame histopatológico e imunofluorescência direta (padrão linear na membrana basal).")
                    print("     - 💊 **Conduta:**  Tratamento com corticosteroides tópicos (ex.: clobetasol gel, uso de moldeiras para gengivite descamativa) ou sistêmicos, dependendo da gravidade. Encaminhamento para oftalmologista devido ao risco de cegueira. Acompanhamento multidisciplinar.\n")

                lupus = input("👄 As lesões ulceradas apresentam estrias radiadas na periferia e o paciente se queixa de fadiga, mal estar e artrite? (sim/nao): ").lower()
                if lupus == 'sim':
                  print("\n➡️ Diagnóstico provável: LÚPUS ERITEMATOSO")
                  print("     - 🤔 **Definição e Etiologia:** Doença autoimune crônica que pode afetar múltiplos órgãos (lúpus eritematoso sistêmico - LES) ou apenas pele e mucosa (lúpus eritematoso cutâneo crônico - LECC).")
                  print("     - 🔴 **Aspecto Clínico:** **LES:** Lesões bucais em 5-25% dos casos, variando de áreas granulomatosas a liquenoides ou ulceradas. Exantema malar (vermelhidão em asa de borboleta sobre o nariz e bochechas) é comum. Sintomas sistêmicos: febre, perda de peso, artrite, fadiga, mal-estar. Complicação grave: insuficiência renal. **LECC:** Lesões em pele (áreas expostas ao sol) com descamação, atrofia e alterações de pigmentação. Lesões bucais semelhantes às do líquen plano erosivo (áreas eritematosas, atróficas, com ulceração central e estrias brancas radiadas na periferia).")
                  print("     - 🔬 **Como Estabelecer o Diagnóstico:**  Avaliação clínica e exames laboratoriais (hemograma, FAN, anticorpos específicos). Biópsia das lesões pode auxiliar no diagnóstico. Critérios diagnósticos bem definidos para LES.")
                  print("     - 💊 **Conduta:**  Tratamento com corticosteroides e outros imunossupressores, coordenado por reumatologista ou dermatologista. Proteção solar é fundamental. Prognóstico variável, dependendo do tipo e gravidade da doença. \n")

        else:
            # Passo 3: Sintomas sistêmicos (febre, perda de peso, mal-estar)
            sintomas_sistemicos = input("🤒 O paciente apresenta sintomas sistêmicos como febre, perda de peso e mal-estar? (sim/nao): ").lower()
            if sintomas_sistemicos == "sim":
              pele = input("🤔 O paciente também apresenta placas mucosas esbranquiçadas e/ou erupções cutâneas avermelhadas, principalmente em palmas das mãos e plantas dos pés? (sim/nao): ").lower()
              if pele == "sim":
                print("\n➡️ Diagnóstico provável: SÍFILIS SECUNDÁRIA")
                print("     - 🦠 **Definição e Etiologia:** Segundo estágio da sífilis, infecção sexualmente transmissível causada pela bactéria *Treponema pallidum*. Ocorre após a sífilis primária (cancro) ou após um período de latência.")
                print("     - 🔴 **Aspecto Clínico:** Sintomas sistêmicos: linfadenopatia, dor de garganta, mal-estar, cefaleia, perda de peso, dores musculares. Lesões cutâneas: erupções maculopapulares (roséolas sifilíticas) em tronco, palmas das mãos e plantas dos pés. Lesões bucais: placas mucosas (áreas brancas acinzentadas) são as mais comuns, mas podem ocorrer úlceras. Condiloma lata (lesões papilares) também pode ocorrer.")
                print("     - 🔬 **Como Estabelecer o Diagnóstico:**  Suspeita clínica (sintomas sistêmicos, lesões cutâneas e bucais). Exames sorológicos confirmatórios: VDRL e FTA-ABS. História de cancro sifilítico (nem sempre presente ou lembrado).")
                print("     - 💊 **Conduta:**  Tratamento com penicilina. Rastreamento e tratamento de parceiros sexuais. Acompanhamento sorológico. Orientação sobre a doença e prevenção. Investigar outras ISTs, como HIV.\n")
              else:
                tosse = input("🗣️ O paciente relata tosse persistente? (sim/nao): ").lower()
                if tosse == 'sim':
                  print("\n➡️  Possíveis diagnósticos baseado em sintomas adicionais:")
                  localizacao = input("📍 A lesão ulcerada está localizada na língua, palato ou lábio? (sim/nao): ").lower()
                  if localizacao == 'sim':
                    print("\n➡️ Diagnóstico provável: TUBERCULOSE")
                    print("     - 🦠 **Definição e Etiologia:** Infecção bacteriana causada pelo *Mycobacterium tuberculosis*. A tuberculose pulmonar é a forma mais comum. A tuberculose oral é rara e geralmente secundária à infecção pulmonar.")
                    print("     - 🔴 **Aspecto Clínico:** Sintomas sistêmicos: febre baixa, sudorese noturna, mal-estar, perda de peso, tosse, dor torácica. Lesões bucais: úlcera crônica indolor, mais comum em língua, palato e lábio. Linfadenopatia regional pode ocorrer.")
                    print("     - 🔬 **Como Estabelecer o Diagnóstico:**  Suspeita clínica (sintomas sistêmicos, tosse, lesão bucal). Radiografia de tórax. Teste tuberculínico (PPD). Biópsia da lesão oral pode mostrar granulomas com necrose caseosa e bacilos álcool-ácido resistentes (BAAR). Cultura de escarro ou da lesão.")
                    print("     - 💊 **Conduta:**  Encaminhar para pneumologista. Tratamento com esquema antibiótico específico para tuberculose (rifampicina, isoniazida, pirazinamida, etambutol). Acompanhamento rigoroso. Investigar contatos próximos.\n")
                  else:
                    imunossup = input("💊 O paciente é imunossuprimido? (sim/nao): ").lower()
                    if imunossup == 'sim':
                        print("\n➡️ Diagnóstico provável: HISTOPLASMOSE")
                        print("     - 🍄 **Definição e Etiologia:** Infecção fúngica sistêmica causada pelo *Histoplasma capsulatum*. A histoplasmose pulmonar é a forma mais comum. A forma disseminada, que inclui manifestações orais, é mais comum em imunossuprimidos.")
                        print("     - 🔴 **Aspecto Clínico:** Sintomas sistêmicos: febre, cefaleia, mialgia, tosse, perda de peso. Lesões bucais: úlcera solitária, dolorosa ou não, com margens firmes e elevadas. Localizações mais comuns: língua, palato e mucosa jugal.")
                        print("     - 🔬 **Como Estabelecer o Diagnóstico:**  Suspeita clínica (sintomas sistêmicos, lesão bucal, imunossupressão). Radiografia de tórax. Exames sorológicos (detecção de anticorpos anti-*H. capsulatum*). Biópsia da lesão oral pode mostrar leveduras dentro de macrófagos. Cultura do material da lesão.")
                        print("     - 💊 **Conduta:**  Encaminhar para infectologista. Tratamento com antifúngicos sistêmicos (anfotericina B, itraconazol). Prognóstico reservado na forma disseminada.\n")
                    else:
                        print("\n➡️ Diagnóstico provável: PARACOCCIDIOIDOMICOSE")
                        print("     - 🍄 **Definição e Etiologia:** Infecção fúngica sistêmica causada pelo *Paracoccidioides brasiliensis*. Endêmica em certas regiões da América Latina, incluindo o sul do Brasil.")
                        print("     - 🔴 **Aspecto Clínico:** Sintomas sistêmicos: tosse, febre baixa, sudorese noturna, perda de peso. Lesões pulmonares são as mais comuns. Lesões bucais: úlceras de contornos irregulares, com superfície granulomatosa e pontos hemorrágicos (aspecto moriforme). Localizações mais comuns: lábios, orofaringe, mucosa jugal e gengiva. Dor durante a mastigação. Linfadenopatia regional.")
                        print("     - 🔬 **Como Estabelecer o Diagnóstico:**  Suspeita clínica (sintomas sistêmicos, lesões bucais com aspecto moriforme, epidemiologia). Exame microscópico direto do material da lesão (esfregaço) pode revelar a presença de leveduras multibrotantes características. Cultura do material da lesão. Sorologia (detecção de anticorpos anti-*P. brasiliensis*). Biópsia da lesão.")
                        print("     - 💊 **Conduta:** Encaminhar para infectologista. Tratamento com antifúngicos sistêmicos (itraconazol, sulfametoxazol-trimetoprima, anfotericina B). Acompanhamento prolongado.\n")
                else:
                  # Na ausência de tosse, mas com sintomas sistêmicos, considerar infecções fúngicas mesmo assim
                  print("\n➡️ Possível diagnóstico: INFECÇÃO FÚNGICA (Histoplasmose ou Paracoccidioidomicose)")
                  print("     - 🍄 **Definição e Etiologia:** Infecções fúngicas que podem se apresentar de forma disseminada, com manifestações bucais, em pacientes imunocomprometidos ou de áreas endêmicas.")
                  print("     - 🔴 **Aspecto Clínico:**  Úlceras crônicas que podem ser dolorosas ou indolores. Na histoplasmose, as margens podem ser firmes e elevadas. Na paracoccidioidomicose, as úlceras podem apresentar superfície granulomatosa e pontos hemorrágicos (aspecto moriforme). Sintomas sistêmicos associados (febre, perda de peso, mal-estar).")
                  print("     - 🔬 **Como Estabelecer o Diagnóstico:**  Biópsia da lesão e exames complementares (cultura, sorologia) são fundamentais. Investigar imunossupressão e/ou exposição a fatores de risco (ex.: áreas endêmicas para paracoccidioidomicose).")
                  print("     - 💊 **Conduta:**  Encaminhar para infectologista. Tratamento com antifúngicos sistêmicos. Prognóstico variável, dependendo da condição imunológica do paciente e da extensão da doença.\n")




            else:
                # Passo 4: Sem sintomas sistêmicos, sem trauma, sem recorrência
                print("\n❗ **Suspeita de malignidade - Investigar:**")
                print("     - ⚠️ **Características que levantam suspeita de malignidade:** Lesão ulcerada crônica, indolor (em estágios iniciais), com bordas elevadas e endurecidas, que não cicatriza após 14 dias, localizada em áreas de alto risco (língua, assoalho bucal).")

                borda_lingua = input("👅 A lesão está localizada em borda de língua, assoalho bucal ou lábio inferior? (sim/nao): ").lower()
                if borda_lingua == "sim":
                    print("\n➡️ Diagnóstico provável: CARCINOMA ESPINOCELULAR (CEC)")
                    print("     - 🔬 **Definição e Etiologia:** Neoplasia maligna mais comum da cavidade bucal, originária do epitélio escamoso estratificado. Fatores de risco: tabagismo, etilismo, infecção por HPV, imunossupressão.")
                    print("     - 🔴 **Aspecto Clínico:** Lesão ulcerada com bordas elevadas e endurecidas (infiltração tumoral). Pode ser precedida por leucoplasia ou eritroplasia. Indolor em estágios iniciais, mas pode causar dor, parestesia e dificuldade para deglutir/falar em estágios avançados. Metástase para linfonodos cervicais é comum. Localizações mais comuns: borda lateral e ventre de língua, assoalho bucal, lábio inferior (associado à exposição solar).")
                    print("     - 🔬 **Como Estabelecer o Diagnóstico:**  Biópsia incisional (incluindo margem da lesão e tecido aparentemente normal). Exame histopatológico é fundamental para o diagnóstico definitivo. Exames de imagem (tomografia computadorizada, ressonância magnética) para avaliar extensão da lesão e metástases.")
                    print("     - 🚨 **Conduta:** Encaminhar *imediatamente* para cirurgião de cabeça e pescoço. O tratamento depende do estadiamento do tumor e pode incluir cirurgia, radioterapia e/ou quimioterapia. Prognóstico depende do tamanho do tumor, localização, presença de metástases e condição geral do paciente.\n")

                palato = input("👄 A lesão está localizada em palato? (sim/nao): ").lower()
                if palato == 'sim':
                  print("\n➡️ Diagnóstico provável: TUMOR MALIGNO DE GLÂNDULA SALIVAR")
                  print("     - 🔬 **Definição e Etiologia:** Grupo heterogêneo de neoplasias malignas originárias das glândulas salivares. Carcinoma adenoide cístico, carcinoma mucoepidermoide e adenocarcinoma são os tipos mais comuns.")
                  print("     - 🔴 **Aspecto Clínico:**  Apresenta-se como um nódulo que pode ulcerar. Crescimento lento. Dor pode estar presente. Localização mais comum: palato (glândulas salivares menores).")
                  print("     - 🔬 **Como Estabelecer o Diagnóstico:**  Biópsia incisional. Exame histopatológico é fundamental para o diagnóstico definitivo e para determinar o tipo histológico. Exames de imagem (tomografia computadorizada, ressonância magnética) para avaliar extensão da lesão.")
                  print("     - 🚨 **Conduta:**  Encaminhar para cirurgião de cabeça e pescoço. O tratamento depende do tipo histológico, estadiamento do tumor e localização. Cirurgia é o tratamento principal, podendo ser associada à radioterapia. Prognóstico variável, dependendo do tipo histológico e estadiamento.\n")
                else:
                  linfonodos = input("🪢 Há linfonodos aumentados, endurecidos e fixos à palpação, associados a um rápido crescimento e destruição da lesão? (sim/nao): ").lower()
                  if linfonodos == 'sim':
                    print("\n➡️ Diagnóstico provável: LINFOMA")
                    print("     - 🧬 **Definição e Etiologia:** Grupo heterogêneo de neoplasias malignas do sistema linfático. Linfoma não-Hodgkin é mais comum em boca. Associação com vírus Epstein-Barr (EBV) e imunossupressão (ex.: HIV, transplantados).")
                    print("     - 🔴 **Aspecto Clínico:**  Aumento de volume, frequentemente ulcerado, de crescimento rápido. Pode causar destruição óssea (ex.: “dentes flutuantes” em radiografias). Localizações mais comuns: tonsilas, palato, gengiva e língua. Linfadenopatia cervical é comum. Sintomas sistêmicos (febre, perda de peso, sudorese noturna) podem estar presentes.")
                    print("     - 🔬 **Como Estabelecer o Diagnóstico:**  Biópsia incisional. Exame histopatológico e imuno-histoquímico são fundamentais para o diagnóstico e classificação do linfoma. Exames de imagem (tomografia computadorizada, PET-CT) para avaliar a extensão da doença.")
                    print("     - 🚨 **Conduta:**  Encaminhar para hematologista/oncologista. Tratamento geralmente envolve quimioterapia, radioterapia ou uma combinação de ambas. Prognóstico variável, dependendo do tipo e estadiamento do linfoma.\n")

# Chamando a função para iniciar o diagnóstico
diagnostico_lesoes_ulceradas_cronicas()
# Out:
#          Texto centralizado com margens.
# 🎯 Diagnóstico de Lesões Ulceradas Crônicas na Mucosa Bucal 🎯
#
# 🤕 Houve trauma ou outro fator irritativo associado? (sim/nao): nao
# 🔁 A lesão tem histórico de recorrência (aparece e desaparece)? (sim/nao): sim
# ⏳ Quando a lesão aparece, ela tem uma duração curta (dias) ou longa (semanas)? (curta/longa): curta
# 👅 A lesão aparece em mucosa ceratinizada (gengiva inserida e palato duro)? (sim/nao): nao
#
# ➡️  Diagnóstico provável: ULCERAÇÃO AFTOSA RECORRENTE (UAR)
#      - ❓ **Definição e Etiologia:** Condição idiopática (causa desconhecida) caracterizada por úlceras recorrentes em mucosa bucal não ceratinizada. Fatores predisponentes: estresse, alergias, deficiências nutricionais, trauma, predisposição genética.
# ...
