# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/drive/1_ipvFuQE6IGMfvlz37dDnEaCYMyBX2hK?usp=sharing)

# %% [markdown]
# ⚕️Estomatologia - Lesões Pigmentadas⚕️

# %%
import textwrap
import shutil # shutil and the formatting functions are not strictly used, but kept for consistency with the example

# Formatting settings (kept for consistency, but simple print is used)
margem = 2
largura_terminal = 90 # Increased width for more detailed descriptions
largura_util = largura_terminal - 2 * margem

def print_centralizado(texto):
    """Helper function to print centered text (optional)."""
    linhas = textwrap.wrap(texto, width=largura_util)
    for linha in linhas:
        print(" " * margem + linha.center(largura_util) + " " * margem)

def diagnostico_lesoes_pigmentadas():


    print("\n🎨 Diagnóstico Auxiliar de Lesões Pigmentadas na Mucosa Bucal 🎨\n")
    print("Baseado no material do Módulo 8 - Curso de Estomatologia para Cirurgiões-Dentistas da Rede Pública.")
    print("Lembre-se: Este guia NÃO substitui a avaliação clínica e exames por um profissional.\n")

    tipo_lesao = input("1. As lesões são predominantemente Difusas e Bilaterais ou Focais (localizadas)? (difusas/focais): ").lower()

    # -------------------------------------------------------------
    # ----- CAMINHO 1: LESÕES DIFUSAS E BILATERAIS --------------
    # -------------------------------------------------------------
    if tipo_lesao == "difusas":
        print("\n-- Avaliando Lesões Difusas e Bilaterais --")
        inicio = input("2. O início da pigmentação foi precoce (infância/adolescência) ou predominantemente na idade adulta? (precoce/adulta): ").lower()

        # --- 1.1 Início Precoce ---
        if inicio == "precoce":
            print("\n----- Hipóteses para Início Precoce (Difusas/Bilaterais) -----")

            print("\n➡️ Hipótese 1: PIGMENTAÇÃO FISIOLÓGICA (RACIAL)")
            print("   - 🧬 **Características:** Comum em peles escuras, desenvolve nas primeiras duas décadas. Coloração castanha, intensidade variável. Frequentemente como banda bilateral bem demarcada na gengiva marginal (poupando gengiva inserida), mas pode ocorrer em mucosa jugal, palato, lábios, língua (bordas menos definidas). Assintomática.")
            print("   - ✅ **Conduta:** Nenhum tratamento é necessário. Acompanhamento para confirmar estabilidade.")

            print("\n➡️ Hipótese 2: SÍNDROME DE PEUTZ-JEGHERS")
            print("   - 🧬 **Características:** Desordem genética rara (gene LKB1). Pequenos pontos (máculas) múltiplos (<5mm) periorais (ao redor dos lábios), intraorais (mucosa bucal), nasal, conjuntiva, reto, pele das extremidades. Associada a pólipos intestinais hamartomatosos e risco aumentado de câncer (intestino, estômago, pâncreas, mama, genital).")
            print("   - ❓ **Perguntas Adicionais:** Há história familiar da síndrome? Há queixa de dor abdominal, sangramento intestinal?")
            print("   - ✅ **Conduta:** Lesões pigmentadas não requerem tratamento e não malignizam. **Encaminhar para avaliação médica (Gastroenterologista)** para investigar pólipos e risco de câncer.")

        # --- 1.2 Início na Idade Adulta ---
        elif inicio == "adulta":
            print("\n-- Avaliando Lesões Difusas/Bilaterais de Início na Idade Adulta --")
            sistemicos = input("3. Há Sinais/sintomas sistêmicos associados (ex: mal-estar, fadiga, fraqueza, perda de peso, náusea/vômito, hipotensão, febre, sinais de imunossupressão)? (sim/nao): ").lower()

            # --- 1.2.1 Com Sinais Sistêmicos ---
            if sistemicos == "sim":
                print("\n----- Hipóteses com Sinais Sistêmicos (Início Adulto, Difusas/Bilaterais) -----")

                print("\n➡️ Hipótese 1: DOENÇA DE ADDISON (Hipoadrenalismo Primário)")
                print("   - 🤒 **Características:** Destruição das adrenais -> baixo cortisol -> alto ACTH -> estimula melanócitos. Pigmentação difusa castanha na pele (áreas de pressão) e mucosas (gengiva, jugal, palato, língua) que surge ou progride na vida adulta. Acompanhada de sintomas sistêmicos (fraqueza, fadiga, náusea, vômito, dor abdominal, constipação/diarreia, perda de peso, hipotensão). Pode ser a primeira manifestação.")
                print("   - ✅ **Conduta:** **Encaminhar para avaliação médica (Endocrinologista)** para diagnóstico (níveis de ACTH, cortisol, eletrólitos) e tratamento. Pode ser fatal se não tratada.")

                print("\n➡️ Hipótese 2: PIGMENTAÇÃO POR METAL PESADO")
                print("   - 🏭 **Características:** Raro hoje. Exposição a chumbo, bismuto, mercúrio, prata, arsênico, ouro (ocupacional, água/tinta contaminada, medicamentos antigos). Frequentemente uma linha azulada/preta ao longo da margem gengival (proporcional à inflamação). Pode afetar outros sítios.")
                print("   - ❓ **Perguntas Adicionais:** Há história de exposição ocupacional a metais? Uso de medicamentos antigos/alternativos? Fonte de água?")
                print("   - ✅ **Conduta:** Identificar e eliminar a fonte de exposição. **Encaminhar para avaliação médica** para investigar toxicidade sistêmica. Tratamento da condição gengival associada.")

                print("\n➡️ Hipótese 3: SARCOMA DE KAPOSI (SK)")
                print("   - 🟣 **Características:** Lesão vascular maligna multifocal, associada ao HHV8. Predominantemente em indivíduos HIV+ (indica progressão para AIDS), mas pode ocorrer em outras formas de imunossupressão. Lesões iniciais planas ou elevadas (placas), castanhas ou roxas, frequentemente bilaterais. Lesões avançadas: nódulos vermelho-escuros/arroxeados, podem ulcerar, sangrar, necrosar. Sítios comuns: palato duro, gengiva, língua.")
                print("   - ❓ **Perguntas Adicionais:** Paciente tem diagnóstico de HIV ou outra condição imunossupressora?")
                print("   - ✅ **Conduta:** **Biópsia é necessária para confirmação diagnóstica.** Encaminhar para médico especialista/infectologista para manejo da condição de base e do SK.")

            # --- 1.2.2 Sem Sinais Sistêmicos ---
            elif sistemicos == "nao":
                print("\n----- Hipóteses sem Sinais Sistêmicos (Início Adulto, Difusas/Bilaterais) -----")

                print("\n➡️ Hipótese 1: PIGMENTAÇÃO INDUZIDA POR MEDICAMENTOS")
                print("   - 💊 **Características:** Diversos medicamentos podem causar (ver Tabela 1 no PDF - ex: antimaláricos, minociclina, contraceptivos orais, zidovudina, etc.). Mecanismos variados. Aparência varia: azul-acinzentada, castanha, preta. Antimaláricos (cloroquina): comum no palato duro (azul-acinzentado/preto). Minociclina: pode pigmentar osso alveolar (visto como mancha acinzentada na gengiva, maxila anterior), língua, esclera, unhas.")
                print("   - ❓ **Perguntas Adicionais:** Paciente faz uso de algum medicamento contínuo? (Checar lista Tabela 1).")
                print("   - ✅ **Conduta:** Identificar o medicamento causal. **Discutir com o médico prescritor** a possibilidade de suspensão ou troca. Pigmentação costuma ser reversível após suspensão (pode levar tempo).")

                print("\n➡️ Hipótese 2: PIGMENTAÇÃO PÓS-INFLAMATÓRIA")
                print("   - 🔥 **Características:** Ocorre em áreas de inflamação crônica da mucosa (especialmente Líquen Plano). Mais frequente em peles escuras. Múltiplas áreas de pigmentação castanha a preta, notadas junto às lesões inflamatórias (reticulares, erosivas). Aumento da produção de melanina e acúmulo em macrófagos.")
                print("   - ❓ **Perguntas Adicionais:** Paciente tem diagnóstico ou lesões sugestivas de Líquen Plano ou outra doença inflamatória crônica na boca?")
                print("   - ✅ **Conduta:** Nenhum tratamento específico para a pigmentação. Manejo da doença inflamatória de base.")

                print("\n➡️ Hipótese 3: MELANOSE DO FUMANTE")
                print("   - 🚬 **Características:** Pigmentação causada ou acentuada pelo hábito de fumar (aumento da melanina como defesa). Observada em ~21.5% dos fumantes. Intensidade relacionada à duração/quantidade de fumo. Mais comum em mulheres (sinergia hormonal?). Cor marrom a preta. Sítio mais comum: gengiva vestibular anterior, seguida de mucosa jugal. Fumantes de cachimbo/charuto podem ter na comissura/jugal.")
                print("   - ❓ **Perguntas Adicionais:** Paciente fuma? Quantos cigarros/dia? Há quanto tempo?")
                print("   - ✅ **Conduta:** Aconselhamento para cessação do tabagismo. Pigmentação usualmente desaparece gradualmente (até 3 anos) após parar de fumar. **Biópsia indicada se:** superfície elevada, aumento rápido da intensidade, ou localização atípica (para descartar outras lesões, incluindo melanoma).")

            else:
                print("\n❌ Resposta inválida para sinais sistêmicos. Tente 'sim' ou 'nao'.")
        else:
            print("\n❌ Resposta inválida para o início da lesão. Tente 'precoce' ou 'adulta'.")

    # -------------------------------------------------------------
    # ----- CAMINHO 2: LESÕES FOCAIS (LOCALIZADAS) --------------
    # -------------------------------------------------------------
    elif tipo_lesao == "focais":
        print("\n-- Avaliando Lesões Focais --")
        isquemia = input("2. A lesão isquemia (fica pálida/branca) à pressão (diascopia/vitropressão)? (sim/nao): ").lower()

        # --- 2.1 Lesão Focal QUE Isquemia (Blanching Positivo) ---
        if isquemia == "sim":
            print("\n----- Hipóteses para Lesões Focais que Isquemiam (Vasculares Intravasculares) -----")

            print("\n➡️ Hipótese 1: HEMANGIOMA / MALFORMAÇÃO VASCULAR (VM)")
            print("   -🩸 **Características:** Hemangioma (proliferação endotelial benigna, surge na infância, tende a regredir) ou VM (anomalia estrutural, persiste). Lesão plana ou elevada, cor vermelho a arroxeada (depende do vaso e profundidade). Diascopia positiva (sangue dentro dos vasos é deslocado).")
            print("   - ✅ **Conduta:** Maioria assintomática e estável. Acompanhamento. Tratamento (escleroterapia, cirurgia) se dor, hemorragia recorrente, queixa estética ou dúvida diagnóstica.")

            print("\n➡️ Hipótese 2: VARIZES (VARICOSIDADES)")
            print("   - 🩸 **Características:** Veias anormalmente dilatadas. Comuns após 60 anos. Sítio comum: ventre da língua (múltiplas elevações moles, azuladas/arroxeadas). Diascopia positiva.")
            print("   - ✅ **Conduta:** Variação da normalidade associada ao envelhecimento. Nenhum tratamento necessário, a menos que haja trombose ou queixa estética.")

        # --- 2.2 Lesão Focal que NÃO Isquemia (Blanching Negativo) ---
        elif isquemia == "nao":
            print("\n-- Avaliando Lesões Focais que NÃO Isquemiam --")
            print("   (Isso pode incluir sangue extravasado, pigmentos exógenos ou melanina)")

            # Tentativa de diferenciar clinicamente
            tipo_nao_isquemia = input("3. A lesão parece ser: \n   a) Vascular (aspecto de 'mancha roxa', hematoma)? \n   b) Exógena (relacionada a restauração metálica, grafite, corpo estranho)? \n   c) Melanocítica (aspecto de 'pinta' ou 'sinal', cor castanha/preta/azulada)? \n   (Responda: vascular / exogena / melanocitica): ").lower()

            # --- 2.2.1 Vascular Não Isquêmica ---
            if tipo_nao_isquemia == "vascular":
                print("\n----- Hipóteses Vasculares Não Isquêmicas -----")
                print("\n➡️ Hipótese 1: HEMATOMA / EQUIMOSE / PETÉQUIA")
                print("   - 멍 **Características:** Sangue extravasado nos tecidos moles. Lesão plana (mancha) ou elevada (placa). Cor varia com o tempo (vermelho -> roxo -> azul -> esverdeado/amarelado) devido à degradação da hemoglobina. NÃO isquemia à pressão.")
                print("   - ❓ **Perguntas Adicionais:** Houve trauma local recente? Se não, há histórico de distúrbios de coagulação ou plaquetas baixas?")
                print("   - ✅ **Conduta:** Se associado a trauma, geralmente resolve espontaneamente em até 2 semanas. Acompanhamento. **Se espontâneo ou recorrente, encaminhar para avaliação médica** (investigar coagulopatias, trombocitopenia).")

                print("\n➡️ Hipótese 2: TROMBO (em Variz)")
                print("   - 🍇 **Características:** Formação de coágulo dentro de uma variz. Apresenta-se como nódulo firme, azulado/arroxeado. NÃO isquemia à pressão. Comum no lábio inferior e mucosa jugal.")
                print("   - ✅ **Conduta:** Geralmente não requer tratamento. Remoção cirúrgica pode ser considerada por estética ou sintomatologia.")

            # --- 2.2.2 Exógena Não Isquêmica ---
            elif tipo_nao_isquemia == "exogena":
                 print("\n----- Hipóteses Exógenas (Pigmento Externo) -----")
                 print("\n➡️ Hipótese 1: TATUAGEM POR AMÁLGAMA")
                 print("   - ✨ **Características:** Causa mais comum de pigmentação intrabucal focal. Lesão plana (mácula), azulada, acinzentada ou preta, limites variáveis. Comum em gengiva, mucosa alveolar, assoalho bucal, jugal, perto de dentes com restaurações de amálgama (atuais ou passadas) ou após endodontia/cirurgia apical com amálgama. NÃO isquemia.")
                 print("   - ❓ **Perguntas Adicionais:** Há restaurações de amálgama próximas? Houve extração de dente restaurado com amálgama? Cirurgia periapical com amálgama?")
                 print("   - ✅ **Conduta:** **Realizar radiografia periapical/interproximal da área:** pode mostrar grânulos radiopacos se as partículas forem grandes, confirmando o diagnóstico. Se não houver confirmação radiográfica ou houver dúvida (especialmente em palato/gengiva, para descartar melanoma), **biópsia excisional** é indicada.")

                 print("\n➡️ Hipótese 2: PIGMENTAÇÃO POR GRAFITE ou OUTRO CORPO ESTRANHO")
                 print("   -✏️ **Características:** Introdução acidental de grafite (lápis) ou outro material pigmentado na mucosa. Comum em palato de crianças após acidente. Mancha irregular cinza a preta.")
                 print("   - ❓ **Perguntas Adicionais:** Houve algum acidente/trauma envolvendo lápis ou outro objeto pontiagudo na área?")
                 print("   - ✅ **Conduta:** Diagnóstico baseado na história e aspecto clínico. Se houver dúvida (descartar melanoma), **biópsia excisional**.")

            # --- 2.2.3 Melanocítica Não Isquêmica ---
            elif tipo_nao_isquemia == "melanocitica":
                 print("\n----- Hipóteses Melanocíticas (Atenção: Risco de Melanoma!) -----")
                 print("   Avaliação cuidadosa das características clínicas é crucial (ABCDE):")
                 print("   A - Assimetria (Forma irregular?)")
                 print("   B - Bordas (Irregulares, entalhadas, mal definidas?)")
                 print("   C - Cor (Variada - tons de castanho, preto, azul, vermelho, branco?)")
                 print("   D - Diâmetro (> 6 mm?)")
                 print("   E - Evolução (Mudança recente em tamanho, forma, cor, elevação, sintomas?)")

                 # Coletar mais detalhes clínicos
                 diametro_mm = input("4. Qual o diâmetro aproximado da lesão em mm? ")
                 bordas = input("5. As bordas são regulares ou irregulares? (regulares/irregulares): ").lower()
                 cor = input("6. A cor é uniforme ou variada (heterogênea)? (uniforme/variada): ").lower()
                 evolucao = input("7. Houve alguma mudança recente na lesão (tamanho, forma, cor, elevação, sangramento, dor)? (sim/nao): ").lower()
                 localizacao = input("8. Qual a localização principal da lesão (ex: lábio inferior, palato, gengiva, mucosa jugal)? ").lower()

                 # Avaliação Simplificada Baseada nas Respostas (ALERTA: Biópsia quase sempre indicada!)
                 suspeita_maligna = False
                 if bordas == "irregulares" or cor == "variada" or evolucao == "sim":
                     suspeita_maligna = True
                 try:
                     if int(diametro_mm) > 6:
                         suspeita_maligna = True
                 except ValueError:
                     pass # Ignora se não for número
                 if "palato" in localizacao or "gengiva" in localizacao:
                    # Locais de maior risco para melanoma oral
                    print("   ⚠️ Atenção: Palato e gengiva são locais de maior risco para melanoma.")
                    suspeita_maligna = True # Aumentar suspeita para estas localizações


                 print("\n➡️ Hipótese 1: MÁCULA MELANÓTICA ORAL")
                 print("   - ⚫ **Características:** Lesão benigna comum. Aumento da produção de melanina (sem aumento de melanócitos). Geralmente < 1 cm (frequentemente < 6mm), limites bem definidos, cor uniforme (marrom claro a escuro), plana (mácula). Mais comum em lábio inferior, gengiva, jugal, palato. Comportamento benigno.")
                 print("   - ✅ **Conduta:** Embora benigna, a diferenciação clínica do melanoma inicial pode ser impossível. **Biópsia excisional é frequentemente recomendada para diagnóstico definitivo e para descartar melanoma**, especialmente em palato/gengiva ou se houver qualquer característica atípica.")

                 print("\n➡️ Hipótese 2: NEVUS PIGMENTADO ORAL (Intramucoso, Juncional, Composto, Azul)")
                 print("   - 🔵 **Características:** Raro na boca. Tumor benigno de células névicas (melanócitos modificados). Pode ser plano (juncional - marrom escuro) ou elevado/cúpula (intramucoso/composto - marrom claro), ou azulado (nevus azul - profundo). Geralmente < 6mm, simétrico, cor uniforme, bordas regulares.")
                 print("   - ✅ **Conduta:** Difícil diferenciar clinicamente do melanoma inicial, especialmente no palato. Considerado por alguns como potencial precursor. **Recomenda-se fortemente a remoção cirúrgica (biópsia excisional) com exame histopatológico.**")

                 print("\n➡️➡️ Hipótese 3: MELANOMA ORAL (ALTO RISCO!)")
                 print("   - 💀 **Características:** Malignidade rara (<1% cânceres orais) mas agressiva e frequentemente fatal. Proliferação de melanócitos malignos. Sítios mais comuns: PALATO e GENGIVA. Pode iniciar como mancha (similar a mácula/nevus) ou já como massa/nódulo. **Características suspeitas (ABCDE):** Assimetria, Bordas irregulares, Cor variada, Diâmetro > 6mm, Evolução (mudança, crescimento rápido, ulceração, sangramento, dor, destruição óssea). Pode ser amelanótico (sem pigmento).")
                 print("   - 🚨 **Conduta:** **ALTAMENTE SUSPEITO!** Requer **avaliação URGENTE por especialista (Estomatologista / Cirurgião Bucomaxilofacial / Cabeça e Pescoço)**. **Biópsia (incisional ou excisional dependendo do caso) é MANDATÓRIA e URGENTE** para confirmação diagnóstica e estadiamento. Prognóstico ruim, detecção precoce é crucial.")

                 # Mensagem final baseada na suspeita
                 if suspeita_maligna:
                     print("\n   🔥🔥🔥 **ALERTA:** As características descritas são SUSPEITAS para MELANOMA. Encaminhamento e biópsia são URGENTES! 🔥🔥🔥")
                 else:
                     print("\n   ⚠️ **Atenção:** Mesmo com características aparentemente benignas, lesões melanocíticas focais na boca, especialmente em palato e gengiva, requerem biópsia para descartar melanoma com segurança.")


            else:
                 print("\n❌ Resposta inválida para o tipo de lesão não isquêmica. Tente 'vascular', 'exogena' ou 'melanocitica'.")

        else:
            print("\n❌ Resposta inválida para isquemia. Tente 'sim' ou 'nao'.")

    else:
        print("\n❌ Tipo de lesão inválido. Por favor, responda 'difusas' ou 'focais'.")

    print("\n🏁 Fim da Avaliação Auxiliar 🏁")
    print("**REFORÇANDO:** Este script é uma ferramenta de auxílio baseada em informações gerais.")
    print("O diagnóstico definitivo e a conduta apropriada SÓ podem ser estabelecidos por um profissional de saúde qualificado após exame clínico completo, anamnese detalhada e, frequentemente, exames complementares como radiografias e biópsias.")
    print("NÃO TOME DECISÕES CLÍNICAS BASEADO APENAS NESTE SCRIPT.\n")

# Chamando a função para iniciar o diagnóstico
diagnostico_lesoes_pigmentadas()
# Out:
# 🎨 Diagnóstico Auxiliar de Lesões Pigmentadas na Mucosa Bucal 🎨
#
# Baseado no material do Módulo 8 - Curso de Estomatologia para Cirurgiões-Dentistas da Rede Pública.
# Lembre-se: Este guia NÃO substitui a avaliação clínica e exames por um profissional.
#
# 1. As lesões são predominantemente Difusas e Bilaterais ou Focais (localizadas)? (difusas/focais): focais
#
# -- Avaliando Lesões Focais --
# 2. A lesão isquemia (fica pálida/branca) à pressão (diascopia/vitropressão)? (sim/nao): nao
#
# -- Avaliando Lesões Focais que NÃO Isquemiam --
#    (Isso pode incluir sangue extravasado, pigmentos exógenos ou melanina)
# 3. A lesão parece ser:
#    a) Vascular (aspecto de 'mancha roxa', hematoma)?
#    b) Exógena (relacionada a restauração metálica, grafite, corpo estranho)?
#    c) Melanocítica (aspecto de 'pinta' ou 'sinal', cor castanha/preta/azulada)?
#    (Responda: vascular / exogena / melanocitica): melanocitica
#
# ----- Hipóteses Melanocíticas (Atenção: Risco de Melanoma!) -----
# ...
