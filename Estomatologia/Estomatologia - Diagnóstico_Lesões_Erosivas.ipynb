# %%
import textwrap
import shutil

margem = 2
largura_terminal = 50
largura_util = largura_terminal - 2 * margem

texto = "Texto centralizado com margens."
linhas = textwrap.wrap(texto, width=largura_util)
for linha in linhas:
    print(" " * margem + linha.center(largura_util) + " " * margem)



def diagnostico_lesoes_erosivas():
    """
    Função para diagnóstico de lesões erosivas na mucosa bucal
    """

    print("🔴 Diagnóstico de Lesões Erosivas na Mucosa Bucal 🔴\n")

    # Passo 1: Determinar a localização da lesão
    localizacao = input("📍 Qual a localização da lesão? (palato, gengiva, lingua, assoalho, labio, mucosa jugal): ").lower()

    if localizacao == "palato":
        # Passo 2: Diferenciar as lesões em Palato
        sintomas = input("🤒 O paciente apresenta sintomas como dor ou ardência? (sim/nao): ").lower()
        if sintomas == 'sim':
            multiplas = input("📍 A lesão se apresenta em multiplas localidades?(sim/nao):").lower()
            if multiplas == 'sim':
                print("\n➡️ Diagnóstico provável: CANDIDÍASE ATRÓFICA CRÔNICA")
                print("     - 🦠 **Definição e Etiologia:** Infecção fúngica oportunista por *Candida*, frequentemente associada ao uso de próteses removíveis ou totais mal higienizadas, ou que gerem trauma. Diabetes mellitus é um fator de risco importante.")
                print("     - 🔴 **Aspecto Clínico:** Área eritematosa difusa, pontilhada ou granulosa na mucosa de revestimento do palato duro, associada às áreas chapeáveis das próteses. Pode causar ardência ou dor.")
                print("     - 🔬 **Como Estabelecer o Diagnóstico:** Clínico, baseado na aparência, localização da lesão e história de uso de prótese. Não são necessários exames complementares.")
                print("     - 💊 **Conduta:**")
                print("         1. **Orientações sobre próteses:**")
                print("             - Higienização rigorosa das próteses.")
                print("             - Remoção noturna para desinfecção.")
                print("             - Avaliar necessidade de ajuste, reembasamento ou confecção de novas próteses.")
                print("             - **Desinfecção:**")
                print("                 - **Opção 1:** Imersão em solução de hipoclorito de sódio (1 colher de sopa em um copo de água) durante a noite. Lavar em água corrente pela manhã.")
                print("                 - **Opção 2 (recomendada para próteses com base de metal):** Imersão em solução de digluconato de clorexidina 0,2% (manipulada) durante a noite. Lavar em água corrente pela manhã.")
                print("         2. **Tratamento Medicamentoso:**")
                print("             - **Primeira linha (lesões múltiplas ou amplas):** Nistatina suspensão oral 100.000 UI/mL, bochechar 10mL (1 colher de sopa cheia) por 3 minutos, 4 vezes ao dia, por 14 dias. Não comer/beber por 30 minutos após o bochecho. Se estendida para orofaringe, pode engolir (exceto em diabéticos, devido ao açúcar).")
                print("             - **Alternativa (lesões localizadas ou casos não responsivos):** Miconazol 20mg/g gel oral, aplicar uma camada fina na face interna da prótese, 4 vezes ao dia, por 30 dias.")
                print("             - **Casos não responsivos ou suspeita de imunossupressão:** Considerar antifúngicos sistêmicos (Fluconazol 150mg, 1 comprimido por semana, por 2-4 semanas). Investigar imunossupressão (hemograma completo, glicemia em jejum, contagem de plaquetas, VSG, ferro sérico, ácido fólico, vitamina B12, anti-HIV).")
                print("         3. **Reavaliar em 30 dias.**\n")
            else:
                print("\n➡️ Diagnóstico provável: LESÃO ASSOCIADA A TRAUMA POR SEXO ORAL (FELAÇÃO)")
                print("     - 💋 **Definição e Etiologia:** Trauma causado pela estimulação do pênis com a boca, gerando pressão negativa e traumas repetitivos.")
                print("     - 🔴 **Aspecto Clínico:** Lesão avermelhada, normalmente ovalada, única, na região posterior de palato duro/anterior palato mole. Pode causar dor ou ardência.")
                print("     - 🔬 **Como Estabelecer o Diagnóstico:** Baseado na anamnese e aspecto clínico, após descartar candidíase.")
                print("     - 🩹 **Conduta:** Suspender o trauma e observar a regressão da lesão.\n")

        else:
            print("\n➡️ Diagnóstico provável: ESTOMATITE DE CONTATO")
            print("     - 🧪 **Definição e Etiologia:** Reação inflamatória ou de hipersensibilidade associada a algum tipo de material, geralmente acrílico de aparelhos/próteses, devido a alto conteúdo de monômero residual.")
            print("     - 🔴 **Aspecto Clínico:** Áreas avermelhadas/eritematosas limitadas ao local de contato com os aparelhos removíveis. Pode haver ardência e/ou dor no local. Em casos raros, sintomas sistêmicos como queimação, dificuldade de deglutição, edema labial e urticária.")
            print("     - 🔬 **Como Estabelecer o Diagnóstico:** Clínico, por exclusão. Suspeitar inicialmente de candidíase atrófica crônica, mas a lesão não regride após terapia antifúngica.")
            print("     - 🩹 **Conduta:** Reembasamento com condicionadores de tecido, uso de medicação tópica com anti-inflamatórios esteroidais. Resolução com a troca do aparelho protético de resina por metal.\n")

    elif localizacao == "gengiva":
        # Passo 3: Gengivite Descamativa
        print("\n➡️ Diagnóstico provável: GENGIVITE DESCAMATIVA")
        print("     - 🦷 **Definição e Etiologia:** Termo clínico genérico para alteração gengival inflamatória de aspecto erosivo/avermelhado, podendo ser sinal de doenças autoimunes mucocutâneas (líquen plano erosivo, pênfigo vulgar, penfigoide benigno de mucosa).")
        print("     - 🔴 **Aspecto Clínico:** Eritema, edema e ulcerações em mucosa gengival. Descamação do epitélio associada à dor ou ardência. Geralmente, há lesões em outros sítios da boca e na pele.")
        print("     - 🔬 **Como Estabelecer o Diagnóstico:** Biópsia parcial/incisional, exame histopatológico e, às vezes, imunofluorescência são fundamentais para estabelecer o diagnóstico diferencial.")
        print("     - 💊 **Conduta:** O tratamento varia conforme o diagnóstico da doença de base:")
        print("         - **Geral:** Uso de corticoide e imunossupressores/imunomoduladores, associado ao controle periodontal rigoroso.")
        print("         - **Específico para Gengivite Descamativa:**")
        print("             - **Moldeira de Acetato:** Utilizar moldeira de acetato para manter o medicamento em contato com a mucosa.")
        print("             - **Medicação:**")
        print("                 - Propionato de clobetasol 0.05% em gel de carboximetilcelulose em orabase, total 30g (1 bisnaga).")
        print("                 - Aplicar o gel na moldeira e utilizar principalmente à noite (se possível, também durante o dia).")
        print("             - **Importante:** Associar antifúngico para prevenir candidíase secundária.\n")

    elif localizacao == "lingua":
        # Passo 4: Diferenciar as lesões em Língua
        multiplas = input("📍 A lesão se apresenta em multiplas localidades?(sim/nao):").lower()
        if multiplas == 'sim':
            sintomas = input("🤒 O paciente apresenta sintomas como dor ou ardência? (sim/nao): ").lower()
            if sintomas == 'sim':
                print("\n➡️ Diagnóstico provável: CANDIDÍASE ATRÓFICA AGUDA")
                print("     - 🦠 **Definição e Etiologia:** Forma de candidíase eritematosa associada a uso crônico de antibióticos, xerostomia e imunossupressão.")
                print("     - 🔴 **Aspecto Clínico:** Erosão/vermelhidão do dorso lingual de forma difusa, associada à sensação de queimação. Língua com aspecto semelhante à glossite atrófica (língua careca).")
                print("     - 🔬 **Como Estabelecer o Diagnóstico:** Clínico. Investigar possível comprometimento sistêmico.")
                print("     - 💊 **Conduta:**")
                print("         - **Primeira linha:** Antifúngicos tópicos.")
                print("         - **Se não houver resposta:** Antifúngicos sistêmicos.")
                print("         - **Investigação:** Avaliar possível comprometimento sistêmico para descartar glossite atrófica.\n")
            else:
                print("\n➡️ Diagnóstico provável: LÍNGUA GEOGRÁFICA")
                print("     - 🗺️ **Definição e Etiologia:** Desordem inflamatória de etiologia desconhecida.")
                print("     - 🔴 **Aspecto Clínico:** Áreas despapiladas, lisas, levemente avermelhadas, que mudam de local com episódios de exacerbações e remissões (geralmente em dorso, bordas e ápice). Pode haver linha esbranquiçada em torno das erosões. Sintomas variam de ardência local até dor e queimação, principalmente associadas a alimentos ácidos, quentes, picantes e condimentados. Imunossuprimidos podem apresentar maior profundidade das erosões e mais sintomas.")
                print("     - 🔬 **Como Estabelecer o Diagnóstico:** Clínico. Não são necessários exames complementares.")
                print("     - 💊 **Conduta:** Geralmente não requer tratamento. Medicamentos tópicos anti-inflamatórios podem aliviar a sintomatologia.\n")
        else:
            sintomas = input("🤒 O paciente apresenta sintomas como dor ou ardência? (sim/nao): ").lower()
            if sintomas == 'sim':
                print("\n➡️ Diagnóstico provável: GLOSSITE ATRÓFICA")
                print("     - 👅 **Definição e Etiologia:** Despapilamento do dorso lingual, podendo ser localizado, multifocal ou generalizado. Associada a carência nutricional (deficiência de vitamina B, ácido fólico), anemia, diabetes e outras debilidades sistêmicas.")
                print("     - 🔴 **Aspecto Clínico:** Eritema difuso devido à ausência ou atrofia das papilas, deixando um aspecto liso (língua careca). Pode haver infecção secundária sobreposta (geralmente *Candida*). Conforme o grau de atrofia, pode haver ardência, dor ou queimação.")
                print("     - 🔬 **Como Estabelecer o Diagnóstico:** Clínico e investigação laboratorial (hemograma, glicemia em jejum, níveis séricos de vitamina B12, ácido fólico e ferritina).")
                print("     - 💊 **Conduta:**")
                print("         - **Infecção Secundária:** Prescrever antifúngico (tratamento promove apenas diminuição da sintomatologia).")
                print("         - **Alteração Sistêmica:** Encaminhar ao médico para diagnóstico e tratamento das alterações sistêmicas ou imunológicas. A reepitelização só irá ocorrer quando a alteração for corrigida.\n")

            else:
                print("\n➡️ Diagnóstico provável: GLOSSITE ROMBOIDAL MEDIANA")
                print("     - 🔷 **Definição e Etiologia:** Quadro inflamatório da porção medial do dorso da língua, em associação direta com a infecção oportunista pela *Candida albicans* (podendo ser uma manifestação clínica de candidíase eritematosa no dorso lingual).")
                print("     - 🔴 **Aspecto Clínico:** Área despapilada, avermelhada, central no dorso de língua, com forma ovalada ou romboide. Pode ser levemente nodulares ou fissuradas. Frequentemente, observa-se “lesão beijada” no palato duro (espelhamento da lesão). Pode haver discreta sintomatologia de ardência.")
                print("     - 🔬 **Como Estabelecer o Diagnóstico:** Clínico.")
                print("     - 💊 **Conduta:** Tratamento medicamentoso com antifúngicos, como descrito para os quadros de candidíases.\n")

    elif localizacao == "assoalho":
        # Passo 5: Avaliar possibilidade de Eritroplasia/Eritroleucoplasia
        print("\n➡️ Diagnóstico provável: ERITROPLASIA/ERITROLEUCOPLASIA ou LÍQUEN PLANO EROSIVO")
        print("     - 🚩 **Definição e Etiologia:**")
        print("         - **Eritroplasia/Eritroleucoplasia:** Desordens potencialmente malignas. A eritroleucoplasia é um subtipo de leucoplasia, sendo uma lesão avermelhada com placas ou manchas esbranquiçadas. Áreas avermelhadas com maior grau de displasia epitelial. Principal fator etiológico é o fumo.")
        print("         - **Líquen Plano Erosivo:** Doença autoimune.")
        print("     - 🔴 **Aspecto Clínico:**")
        print("         - **Eritroplasia/Eritroleucoplasia:** Mancha vermelha (eritroplasia) ou mancha vermelha com placas ou manchas esbranquiçadas (eritroleucoplasia).")
        print("         - **Líquen Plano Erosivo:** Áreas de atrofia e eritema circundadas por finas estrias brancas.")
        print("     - 🔬 **Como Estabelecer o Diagnóstico:**")
        print("         - **Eritroplasia/Eritroleucoplasia:** Biópsia é mandatória (maior parte dos casos são carcinoma espinocelular). Diagnóstico clínico é de exclusão.")
        print("         - **Líquen Plano Erosivo:** Biópsia incisional/parcial.")
        print("     - 💊 **Conduta:**")
        print("         - **Eritroplasia/Eritroleucoplasia:** Suspensão do fumo e remoção total da lesão, quando possível. Acompanhamento: semestral (sem displasia), trimestral (com displasia). Se carcinoma espinocelular, encaminhar para cirurgião de cabeça e pescoço.")
        print("         - **Líquen Plano Erosivo:** Corticoterapia tópica ou sistêmica. Acompanhamento rigoroso. Dificilmente o paciente vai apresentar lesão apenas no assoalho, multiplas lesões. nao biopsiar lesoes de assoalho de boca devido a grande quantidade de estruturas anatômicas, local de biopsia deve ser pensando na facilidade de acesso e no periodo pos operatorio\n")

    elif localizacao == "labio":
        # Passo 6: Diferenciar as lesões em Lábio
        multiplas = input("📍 A lesão se apresenta em multiplas localidades?(sim/nao):").lower()
        if multiplas == 'sim':
            print("\n➡️ Diagnóstico provável: QUEILITE ANGULAR")
            print("     - 👄 **Definição e Etiologia:** Forma de candidíase eritematosa nas comissuras labiais.")
            print("     - 🔴 **Aspecto Clínico:** Eritema, fissuras e descamação nas comissuras. Usualmente assintomáticas. Acomete pessoas idosas com redução da dimensão vertical de oclusão e sulcos acentuados nas comissuras labiais. Pacientes imunossuprimidos também podem apresentar essas lesões.")
            print("     - 🔬 **Como Estabelecer o Diagnóstico:** Clínico.")
            print("     - 💊 **Conduta:** Antifúngicos tópicos.\n")

        else:
            print("\n➡️ Diagnóstico provável: QUEILITE ACTÍNICA")
            print("     - ☀️ **Definição e Etiologia:** Desordem potencialmente maligna associada à exposição crônica à luz UV.")
            print("     - 🔴 **Aspecto Clínico:** Áreas brancas (placas ou manchas), áreas erosivas/vermelhas, bem como crostas, fissuras e descamações. As áreas erosivas geralmente possuem aspecto microscópico de maior agressividade (displasia).")
            print("     - 🔬 **Como Estabelecer o Diagnóstico:** Clínico e histopatológico.")
            print("     - 🩹 **Conduta:**")
            print("         - **Prevenção:** Uso diário de protetor labial com FPS 30 e utilização de chapéu de aba larga (especialmente em pacientes expostos ao sol).")
            print("         - **Ressecamento:** Uso de dexpantenol (Bepantol creme, 1 vez/dia, à noite).")
            print("         - **Biópsia:** Áreas de placas, erosões ou úlceras devem ser biopsiadas (podem representar carcinoma espinocelular inicial).")
            print("         - **Revisões Periódicas:**")
            print("             - Trimestrais: quadros que apresentam displasia epitelial.")
            print("             - Semestrais: quadros sem displasia epitelial.\n")

    elif localizacao == "mucosa jugal":
       # Passo 7: Diferenciar as lesões em mucosa jugal
        multiplas = input("📍 A lesão se apresenta em multiplas localidades?(sim/nao):").lower()
        if multiplas == 'sim':
            print("\n➡️ Diagnóstico provável: LÍQUEN PLANO EROSIVO")
            print("     - ⚪🔴 **Definição e Etiologia:** Doença mucocutânea crônica autoimune.")
            print("     - 🔴 **Aspecto Clínico:** Áreas de atrofia e eritema, circundadas por finas estrias brancas (geralmente em mucosa jugal e língua). Pode acometer pele (lesoes em areas flexoras) e mucosa concomitantemente. Associadas a quadros de ardência e dor em boca.")
            print("     - 🔬 **Como Estabelecer o Diagnóstico:** Biópsia incisional/parcial.")
            print("     - 💊 **Conduta:**")
            print("         - **Investigação:** Avaliar presença de lesões em outras localizações, principalmente em áreas flexoras de pele. Encaminhar ao dermatologista se necessário.")
            print("         - **Tratamento:**")
            print("             - **Primeira linha:** Nistatina (suspensão oral) durante uma semana (profilaxia para infecção secundária por cândida).")
            print("             - **Corticosteroides:**")
            print("                 - **Tópico (preferencial):**")
            print("                     - *Opção 1 (gel):* Propionato de clobetasol 0.05%, Gel de hidroxietilcelulose qsp 20g, aplicar nas lesões com cotonete 3 vezes ao dia.")
            print("                     - *Opção 2 (solução - casos com coinfecção por Candida):* Propionato de clobetasol 0.05%, Nistatina 100.000 UI/mL, Água destilada, Conteúdo final = 250mL, bochechar 10mL por 3 minutos e cuspir, evitar comer/beber por 30 minutos.")
            print("                 - **Sistêmico:** Se não houver resposta ao tratamento tópico.")
            print("             - **Atenção:** O propionato de clobetasol é um corticosteroide de alta potência, podendo haver efeitos colaterais sistêmicos com seu uso prolongado.\n")
        else:
            print("\n➡️ Diagnóstico provável: REAÇÕES MEDICAMENTOSAS (MUCOSITE E REAÇÃO LIQUENÓIDE)")
            print("     - 💊 **Definição e Etiologia:**")
            print("         - **Mucosite:** Reação inflamatória comum frente ao tratamento quimioterápico e/ou radioterápico em cabeça e pescoço.")
            print("         - **Reação Liquenoide:** Reação a medicamentos (amálgama, captopril, carbamazepina, alopurinol, fenitoína, furosemida, isoniazida e propranolol) ou amálgama.")
            print("     - 🔴 **Aspecto Clínico:**")
            print("         - **Mucosite:** Se inicia como áreas de eritema e erosão, podendo evoluir para severas ulcerações em mucosa bucal, principalmente não ceratinizada.")
            print("         - **Reação Liquenoide:** Semelhante ao líquen plano.")
            print("     - 🔬 **Como Estabelecer o Diagnóstico:**")
            print("         - **Mucosite:** Clínico. Informação do uso de medicamentos ou radioterapia é fundamental.")
            print("         - **Reação Liquenoide:**  O diagnóstico diferencial e a evolução no processo de obtenção do diagnóstico final se faz após removermos o medicamento ou o material irritativo local.")
            print("     - 🩹 **Conduta:**")
            print("         - **Mucosite:** Tratamento paliativo (acelerar reparo tecidual, diminuir sintomas, controlar infecções/hemorragias). Higiene bucal, antifúngico coadjuvante, laserterapia (analgesia e aceleração do reparo).")
            print("         - **Reação Liquenoide:** Remoção do agente causador (medicamento ou material).")

    else:
        print("\n🙁 Não foi possível determinar um diagnóstico com as informações fornecidas.")
        print("ℹ️ Consulte um especialista para avaliação detalhada.\n")

diagnostico_lesoes_erosivas()
# Out:
#          Texto centralizado com margens.
# 🔴 Diagnóstico de Lesões Erosivas na Mucosa Bucal 🔴
#
# 📍 Qual a localização da lesão? (palato, gengiva, lingua, assoalho, labio, mucosa jugal): palato
# 🤒 O paciente apresenta sintomas como dor ou ardência? (sim/nao):
#
# ➡️ Diagnóstico provável: ESTOMATITE DE CONTATO
#      - 🧪 **Definição e Etiologia:** Reação inflamatória ou de hipersensibilidade associada a algum tipo de material, geralmente acrílico de aparelhos/próteses, devido a alto conteúdo de monômero residual.
#      - 🔴 **Aspecto Clínico:** Áreas avermelhadas/eritematosas limitadas ao local de contato com os aparelhos removíveis. Pode haver ardência e/ou dor no local. Em casos raros, sintomas sistêmicos como queimação, dificuldade de deglutição, edema labial e urticária.
#      - 🔬 **Como Estabelecer o Diagnóstico:** Clínico, por exclusão. Suspeitar inicialmente de candidíase atrófica crônica, mas a lesão não regride após terapia antifúngica.
# ...
