# %%
import textwrap
import shutil

margem = 2
largura_terminal = 50
largura_util = largura_terminal - 2 * margem

texto = "Texto centralizado com margens."
linhas = textwrap.wrap(texto, width=largura_util)
for linha in linhas:
    print(" " * margem + linha.center(largura_util) + " " * margem)


def diagnostico_lesoes_brancas():
    """
    Função para diagnóstico de lesões brancas na mucosa bucal

    """

    print("🦷 Diagnóstico de Lesões Brancas na Mucosa Bucal 🦷\n")

    # Passo 1: Descartar variações da normalidade
    leucoedema_linha_alba = input("🤔 A lesão é Leucoedema ou Linha Alba? (sim/nao): ").lower()
    if leucoedema_linha_alba == "sim":
        print("✅ Variação da normalidade. Não é uma lesão preocupante.\n")
        return

    # Passo 2: Verificar se a lesão é removível por raspagem
    removivel_raspagem = input("🪥 A lesão é removível por raspagem? (sim/nao): ").lower()
    if removivel_raspagem == "sim":
        # Passo 2.1: Queimadura ou Candidíase Pseudomembranosa
        historia = input("🔥 Houve exposição à alta temperatura ou produto químico? (sim/nao): ").lower()
        if historia == "sim":
            print("➡️  Diagnóstico provável: QUEIMADURA")
            print("     - 🌡️ **Definição e Etiologia:** Lesão térmica ou química, gerando necrose superficial da mucosa.")
            print("     - ⚪ **Aspecto Clínico:** Manchas e placas brancas removíveis por raspagem.")
            print("     - 🔬 **Como Estabelecer o Diagnóstico:** Aspecto clínico associado à anamnese.")
            print("     - 🩹 **Conduta:** Caso tenha sido um episódio pontual e involuntário, orientar o paciente. Antissépticos (colutórios sem álcool) podem ajudar. Dependendo dos sintomas, podem ser prescritos analgésicos.\n")

        else:
            print("\n➡️  Diagnóstico provável: CANDIDÍASE PSEUDOMEMBRANOSA")
            print("     - 🦠 **Definição e Etiologia:** Infecção por fungos do tipo Candida (Candida albicans). Fatores locais ou sistêmicos geram um desequilíbrio no meio bucal.")
            print("     - ⚪ **Aspecto Clínico:** Placas múltiplas brancas de contorno arredondado ou irregular, removíveis. Indolores, mas alguns casos mostram ardência. Palato, língua e mucosa jugal são os sítios bucais mais afetados.")
            print("     - 🔬 **Como Estabelecer o Diagnóstico:** Aspecto clínico e destacamento frente a raspagem confirmam o diagnóstico. Comum sobre próteses removíveis e costuma alternar áreas brancas com áreas vermelhas.")
            print("     - 💊 **Conduta:** Eliminar os fatores predisponentes. Antifúngicos tópicos (bochechos com nistatina e aplicação de miconazol gel). Em casos não responsivos, investigação sistêmica e antifúngicos sistêmicos (fluconazol).\n")
    else:
        # Passo 3: Definir se a lesão é única ou múltipla
        lesao_unica = input("🧐 A lesão é única? (sim/nao): ").lower()
        if lesao_unica == "sim":
            # Passo 3.1: Definir se é focal ou difusa
            lesao_difusa = input(" 🫧A lesão é difusa (estende-se por uma área maior)? (sim/nao): ").lower()
            if lesao_difusa == "sim":
                # Passo 3.1.1: Queilite Actínica, Estomatite Nicotínica ou Leucoplasia
                localizacao = input("👄 A lesão está localizada no lábio? (sim/nao): ").lower()
                if localizacao == "sim":
                    print("\n➡️  Diagnóstico provável: QUEILITE ACTÍNICA")
                    print("     - ☀️ **Definição e Etiologia:** Alteração produzida pela exposição crônica à radiação ultravioleta (radiação solar).")
                    print("     - ⚪ **Aspecto Clínico:** Perda de nitidez no limite entre pele e vermelhão do lábio. Observação de placas, áreas descamativas, crostas, áreas erosivas (avermelhadas).")
                    print("     - 🔬 **Como Estabelecer o Diagnóstico:** O diagnóstico se baseia no aspecto clínico das lesões. Presença de úlceras pode indicar malignização.")
                    print("     - 🩹 **Conduta:** Em casos leves, usar protetor labial com FPS 30 e chapéu de aba larga. Em casos mais graves, dexpantenol. Se não houver reversão, áreas de placas, erosões ou úlceras devem ser biopsiadas. Revisões periódicas.\n")
                else:
                    localizacao = input("👄 A lesão está localizada no palato? (sim/não): ").lower()
                    if localizacao == "sim":
                        print("\n➡️  Diagnóstico provável: ESTOMATITE NICOTÍNICA")
                        print("     - 🚬 **Definição e Etiologia:** Lesão branca associada ao calor produzido pelo fumo ou por outro alimento ou bebida quente.")
                        print("     - ⚪ **Aspecto Clínico:** Manchas e/ou placas brancas de limites difusos com pontos avermelhados.")
                        print("     - 🔬 **Como Estabelecer o Diagnóstico:** Clínico, definido pelo aspecto visual das lesões.")
                        print("     - 🩹 **Conduta:** Apesar de o fumo ser o agente causador na maior parte dos casos, a lesão não apresenta risco de transformação maligna. Orientar a respeito da presença e natureza benigna da lesão.\n")
                    else:
                        print("\n➡️  Diagnóstico provável: LEUCOPLASIA (difusa)")
                        print("     - 🚬 **Definição e Etiologia:** Lesão predominantemente branca, não removível a raspagem que não pode ser caracterizada como outra doença. Maior parte dos casos associado ao fumo.")
                        print("     - ⚪ **Aspecto Clínico:** Manchas e/ou placas de coloração branca, únicas ou múltiplas, assintomáticas, principalmente em pacientes fumantes. Mais comuns em mucosa jugal, gengiva e vermelhão do lábio. Lesões em língua e assoalho bucal e de distribuição múltipla costumam ter comportamento mais agressivo.")
                        print("     - 🔬 **Como Estabelecer o Diagnóstico:** Clínico e de exclusão. Realizar biópsia parcial para avaliar microscopicamente a lesão.")
                        print("     - 🩹 **Conduta:** Se a biópsia parcial indicar presença de displasia epitelial, o ideal é remover toda a lesão. Casos com alterações mais brandas podem ser acompanhados. Todos os pacientes devem ser submetidos a controle clínico periódico devido ao risco de transformação maligna. Intervalos entre as consultas variam de 3 a 6 meses. Orientar sobre a importância de suspender a exposição aos fatores de risco.\n")
            else:
                # Passo 3.1.2: Fator irritativo?
                fator_irritativo = input("🔍 Existe algum possível fator irritativo? (sim/nao): ").lower()
                if fator_irritativo == "sim":
                    print("\n➡️  Diagnóstico provável: MORDISCAMENTO CRÔNICO DA MUCOSA (MORSICATIO) ou CERATOSE FRICCIONAL")
                    habito = input("😬 O paciente tem o hábito de morder a região? (sim/nao): ").lower()
                    if habito == "sim":
                        print("\n➡️  Diagnóstico provável: MORDISCAMENTO CRÔNICO DA MUCOSA (MORSICATIO)")
                        print("     - 😬 **Definição e Etiologia:** Lesão benigna provocada pelo hábito de morder a mucosa.")
                        print("     - ⚪ **Aspecto Clínico:** Placas brancas de superfície irregular, associadas ou não a áreas de eritema, geralmente na mucosa jugal na linha de oclusão. Também pode ser vista na língua e no lábio. Podem ser únicas ou múltiplas, dependendo de como o paciente executa o hábito.")
                        print("     - 🔬 **Como Estabelecer o Diagnóstico:** Anamnese e exame físico. Placas brancas mais ou menos espessas em áreas sujeitas ao mordiscamento justificam a pergunta ao paciente.")
                        print("     - 🩹 **Conduta:** Orientação do paciente. Caso haja suspeita de outra doença, pode-se realizar biópsia.\n")
                    else:
                        print("\n➡️  Diagnóstico provável: CERATOSE FRICCIONAL")
                        print("     - 🦷 **Definição e Etiologia:** Aumento da produção de ceratina no tecido epitelial como uma reação frente a agentes traumáticos crônicos. Fricção local causada por agente irritativo crônico (aparelho ortodôntico, dentes fraturados, próteses removíveis, trauma de mastigação sobre rebordo edêntulo).")
                        print("     - ⚪ **Aspecto Clínico:** Mancha ou placa de coloração branca e homogênea, assintomática, superfície lisa ou rugosa.")
                        print("     - 🔬 **Como Estabelecer o Diagnóstico:** Diagnóstico clínico, confirmado quando a lesão desaparece no período de até 4 semanas após a remoção do agente irritativo.")
                        print("     - 🩹 **Conduta:** Identificação e remoção do agente causador. Quando a remoção não é possível, recomenda-se controle clínico periódico e pode-se considerar biópsia.\n")

                else:
                    print("\n➡️  Diagnóstico provável: LEUCOPLASIA (focal)")
                    print("     - 🚬 **Definição e Etiologia:** Lesão predominantemente branca, não removível a raspagem que não pode ser caracterizada como outra doença. Maior parte dos casos associado ao fumo.")
                    print("     - ⚪ **Aspecto Clínico:** Manchas e/ou placas de coloração branca, únicas ou múltiplas, assintomáticas, principalmente em pacientes fumantes. Mais comuns em mucosa jugal, gengiva e vermelhão do lábio. Lesões em língua e assoalho bucal e de distribuição múltipla costumam ter comportamento mais agressivo.")
                    print("     - 🔬 **Como Estabelecer o Diagnóstico:** Clínico e de exclusão. Realizar biópsia parcial para avaliar microscopicamente a lesão.")
                    print("     - 🩹 **Conduta:** Se a biópsia parcial indicar presença de displasia epitelial, o ideal é remover toda a lesão. Casos com alterações mais brandas podem ser acompanhados. Todos os pacientes devem ser submetidos a controle clínico periódico devido ao risco de transformação maligna. Intervalos entre as consultas variam de 3 a 6 meses. Orientar sobre a importância de suspender a exposição aos fatores de risco.\n")

        else:
            # Passo 3.2: Lesões Múltiplas
            # Passo 3.2.1: Fatores irritativos envolvidos?
            fatores_irritativos = input("🔍 Existem fatores irritativos envolvidos? (sim/nao): ").lower()
            if fatores_irritativos == "sim":
                print("\n➡️  Diagnóstico provável: MORDISCAMENTO CRÔNICO ou CERATOSE FRICCIONAL (múltiplos)")
                habito = input("😬 O paciente tem o hábito de morder a região? (sim/não): ").lower()
                if habito == "sim":
                    print("\n➡️  Diagnóstico provável: MORDISCAMENTO CRÔNICO DA MUCOSA (MORSICATIO)")
                    print("     - 😬 **Definição e Etiologia:** Lesão benigna provocada pelo hábito de morder a mucosa.")
                    print("     - ⚪ **Aspecto Clínico:** Placas brancas de superfície irregular, associadas ou não a áreas de eritema, geralmente na mucosa jugal na linha de oclusão. Também pode ser vista na língua e no lábio. Podem ser únicas ou múltiplas, dependendo de como o paciente executa o hábito.")
                    print("     - 🔬 **Como Estabelecer o Diagnóstico:** Anamnese e exame físico. Placas brancas mais ou menos espessas em áreas sujeitas ao mordiscamento justificam a pergunta ao paciente.")
                    print("     - 🩹 **Conduta:** Orientação do paciente. Caso haja suspeita de outra doença, pode-se realizar biópsia.\n")

                else:
                    print("\n➡️  Diagnóstico provável: CERATOSE FRICCIONAL")
                    print("     - 🦷 **Definição e Etiologia:** Aumento da produção de ceratina no tecido epitelial como uma reação frente a agentes traumáticos crônicos. Fricção local causada por agente irritativo crônico (aparelho ortodôntico, dentes fraturados, próteses removíveis, trauma de mastigação sobre rebordo edêntulo).")
                    print("     - ⚪ **Aspecto Clínico:** Mancha ou placa de coloração branca e homogênea, assintomática, superfície lisa ou rugosa.")
                    print("     - 🔬 **Como Estabelecer o Diagnóstico:** Diagnóstico clínico, confirmado quando a lesão desaparece no período de até 4 semanas após a remoção do agente irritativo.")
                    print("     - 🩹 **Conduta:** Identificação e remoção do agente causador. Quando a remoção não é possível, recomenda-se controle clínico periódico e pode-se considerar biópsia.\n")

            else:
                # Passo 3.2.2: Familiar, infância/adolescência?
                historico_familiar = input("👨‍👩‍👧‍👦 Mais pessoas da família apresentam a lesão? Iniciou na infância ou adolescência? (sim/nao): ").lower()
                if historico_familiar == "sim":
                    print("\n➡️  Diagnóstico provável: NEVO BRANCO ESPONJOSO")
                    print("     - 🧬 **Definição e Etiologia:** Genodermatose (doença dos tecidos de revestimento determinada geneticamente).")
                    print("     - ⚪ **Aspecto Clínico:** Placas simétricas, difusas, espessas, corrugadas assintomáticas que se apresentam bilateralmente na mucosa jugal e que não saem à raspagem.")
                    print("     - 🔬 **Como Estabelecer o Diagnóstico:** Anamnese e exame físico. As lesões estão presentes desde o nascimento ou surgem até a adolescência. Mais membros da família costumam estar afetados.")
                    print("     - 🩹 **Conduta:** Não há necessidade de tratamento.\n")

                else:
                    # Passo 3.2.3: Distribuição bilateral?
                    distribuicao_bilateral = input("↔️  Observam-se linhas ou placas brancas com distribuição bilateral? (sim/nao): ").lower()
                    if distribuicao_bilateral == "sim":
                        localizacao = input("👅 A lesão está na borda da língua com aspecto de pelos? (sim/nao): ").lower()
                        if localizacao == "sim":
                            print("\n➡️  Diagnóstico provável: LEUCOPLASIA PILOSA")
                            print("     - 🦠 **Definição e Etiologia:** Infecção pelo vírus do EBV, observada em quadros de imunodeficiência (por exemplo: pacientes HIV positivos).")
                            print("     - ⚪ **Aspecto Clínico:** Estrias paralelas que podem se juntar formando placas localizadas em borda de língua bilateralmente.")
                            print("     - 🔬 **Como Estabelecer o Diagnóstico:** Presença de lesões com a característica descrita ao lado sugere fortemente o diagnóstico, confirmado se o paciente tiver imunossupressão confirmada.")
                            print("     - 🩹 **Conduta:** A lesão não precisa de tratamento específico. Em pacientes HIV positivos, o controle da AIDS costuma induzir melhora nas lesões.\n")

                        else:
                            localizacao = input("⬅️➡️ A lesão está na região de retrocomissura? (sim/nao): ").lower()
                            if localizacao == "sim":
                                print("\n➡️  Diagnóstico provável: CANDIDÍASE HIPERPLÁSICA CRÔNICA")
                                print("     - 🦠 **Definição e Etiologia:** Manifestação incomum da infecção pela Candida albicans. É uma lesão controversa. Alguns autores afirmam que é uma infecção por Candida sobre uma leucoplasia.")
                                print("     - ⚪ **Aspecto Clínico:** Placas brancas não removíveis por raspagem localizadas geralmente na região anterior da mucosa jugal (retrocomissura), apresentando-se bilateralmente.")
                                print("     - 🔬 **Como Estabelecer o Diagnóstico:** O diagnóstico é sugerido pela presença de placas nesta localização específica (retrocomissura).")
                                print("     - 💊 **Conduta:** Tratamento com antifúngicos tópicos. Nem sempre há remissão total das lesões. Neste caso indica-se biópsia parcial para avaliação das alterações microscópicas presentes e para descartar carcinoma espinocelular.\n")
                            else:
                                print("\n➡️  Diagnóstico provável: LÍQUEN PLANO")
                                print("     - ⚪ **Definição e Etiologia:** Doença mucocutânea crônica imunologicamente mediada por linfócitos T. Pode acometer pele e mucosa bucal concomitantemente. Causa desconhecida.")
                                print("     - ⚪ **Aspecto Clínico:** Numerosas estrias ou placas brancas assintomáticas frequente em mulheres de meia idade. Mucosa jugal e lingual bilateral são os sítios mais afetados. Apresenta curso crônico com períodos de remissão e exacerbação, quando podem aparecer áreas erosivas ou ulceradas e dor.")
                                print("     - 🔬 **Como Estabelecer o Diagnóstico:** O diagnóstico final é estabelecido com base no aspecto clinico das estrias e pelos exames histopatológico. Alguns casos exigem uso do exame imunofluorescência direta.")
                                print("     - 💊 **Conduta:** O líquen plano reticular é assintomático na maior parte dos casos, não havendo necessidade de tratamento. Os casos de líquen atrófico/erosivo, ou seja, quando aparecem úlceras ou erosões, situação usualmente associada a dor ou ardência, são situações onde o tratamento com corticosteroides tópicos está indicado. Deve-se reavaliar o paciente a cada 6 meses.\n")

                    else:
                        # Passo 3.2.4: Sinais/sintomas sistêmicos?
                        sintomas_sistemicos = input("🤒 O paciente apresenta sinais/sintomas sistêmicos (dor de garganta, febre, linfadenopatia, dor de cabeça, dores musculares)? (sim/nao): ").lower()
                        if sintomas_sistemicos == "sim":
                            print("\n➡️  Diagnóstico provável: SÍFILIS SECUNDÁRIA")
                            print("     - 🦠 **Definição e Etiologia:** Manifestação da fase secundária da sífilis, geralmente precedida pelo estágio de cancro - sífilis primária, a qual se caracteriza pela presença de úlcera indolor única em genitais ou na boca.")
                            print("     - ⚪ **Aspecto Clínico:** Placas brancas sensíveis. Mais comuns em língua, lábios, mucosa jugal e palato. Podem ser observadas lesões em pele (manchas vermelhas indolores, principalmente na palma das mãos e na planta dos pés.")
                            print("     - 🔬 **Como Estabelecer o Diagnóstico:** Importante perguntar a respeito do estágio prévio (sífilis primária), o que nem sempre é percebido pelo paciente. A associação das manifestações clínicas (lesões bucais, em pele, associadas aos sintomas sugerem a doença, mas o diagnóstico só é confirmado com os exames de sangue (VDRL e FTA-ABS).")
                            print("     - 💊 **Conduta:** Tratamento com penicilina, prescrito pelo médico infectologista. O dentista acompanha a involução das lesões bucais, o que costuma ser observado rapidamente se o paciente faz o tratamento adequadamente.\n")
                        else:
                            print("\n➡️  Diagnóstico provável: LEUCOPLASIA (múltipla)")
                            print("     - 🚬 **Definição e Etiologia:** Lesão predominantemente branca, não removível a raspagem que não pode ser caracterizada como outra doença. Maior parte dos casos associado ao fumo.")
                            print("     - ⚪ **Aspecto Clínico:** Manchas e/ou placas de coloração branca, únicas ou múltiplas, assintomáticas, principalmente em pacientes fumantes. Mais comuns em mucosa jugal, gengiva e vermelhão do lábio. Lesões em língua e assoalho bucal e de distribuição múltipla costumam ter comportamento mais agressivo.")
                            print("     - 🔬 **Como Estabelecer o Diagnóstico:** Clínico e de exclusão. Realizar biópsia parcial para avaliar microscopicamente a lesão.")
                            print("     - 🩹 **Conduta:** Se a biópsia parcial indicar presença de displasia epitelial, o ideal é remover toda a lesão. Casos com alterações mais brandas podem ser acompanhados. Todos os pacientes devem ser submetidos a controle clínico periódico devido ao risco de transformação maligna. Intervalos entre as consultas variam de 3 a 6 meses. Orientar sobre a importância de suspender a exposição aos fatores de risco.\n")
# Chamando a função para iniciar o diagnóstico
diagnostico_lesoes_brancas()
# Out:
#          Texto centralizado com margens.
# 🦷 Diagnóstico de Lesões Brancas na Mucosa Bucal 🦷
#
# 🤔 A lesão é Leucoedema ou Linha Alba? (sim/nao): nao
# 🪥 A lesão é removível por raspagem? (sim/nao): nao
# 🧐 A lesão é única? (sim/nao): nao
# 🔍 Existem fatores irritativos envolvidos? (sim/nao): nao
# 👨‍👩‍👧‍👦 Mais pessoas da família apresentam a lesão? Iniciou na infância ou adolescência? (sim/nao): nao
# ↔️  Observam-se linhas ou placas brancas com distribuição bilateral? (sim/nao): nao
# 🤒 O paciente apresenta sinais/sintomas sistêmicos (dor de garganta, febre, linfadenopatia, dor de cabeça, dores musculares)? (sim/nao): nao
#
# ➡️  Diagnóstico provável: LEUCOPLASIA (múltipla)
#      - 🚬 **Definição e Etiologia:** Lesão predominantemente branca, não removível a raspagem que não pode ser caracterizada como outra doença. Maior parte dos casos associado ao fumo.
# ...
