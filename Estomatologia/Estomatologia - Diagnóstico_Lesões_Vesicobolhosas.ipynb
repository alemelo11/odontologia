# %%
import textwrap
import shutil

# Configurações de formatação
margem = 2
largura_terminal = 50
largura_util = largura_terminal - 2 * margem

texto = "Texto centralizado com margens."
linhas = textwrap.wrap(texto, width=largura_util)
for linha in linhas:
    print(" " * margem + linha.center(largura_util) + " " * margem)

def diagnostico_lesoes_vesicobolhosas():
    """
    Função para diagnóstico de lesões vesicobolhosas na mucosa bucal.
    """

    print("🦷 Diagnóstico de Lesões Vesicobolhosas na Mucosa Bucal 🦷\n")

    # Passo 1: Determinar o número de lesões
    num_lesoes = input("🤔 A lesão é única ou múltipla? (u/m): ").lower()

    if num_lesoes == "u":
        # Lesão Única
        print("\n➡️  Lesão ÚNICA identificada.")

        # Passo 2: Determinar a coloração do líquido em lesão única
        print("\n➡️  QUAL A COLORAÇÃO DO LÍQUIDO?")
        cor_liquido = input("🤔 O líquido é translúcido, azulado ou arroxeado/enegrecido? (t/a/r): ").lower()

        if cor_liquido == "t":
            print("\n➡️  Líquido TRANSLÚCIDO.")
            print("   - Possibilidades: Mucocele, Rânula, Herpes labial recorrente*, Pênfigo vulgar*, Penfigoide benigno de membranas mucosas*")
            print("   - *OBS: Herpes labial recorrente, Pênfigo vulgar e Penfigoide benigno de membranas mucosas dificilmente são diagnosticadas na fase de vesícula/bolha, pois essas lesões rompem-se facilmente.")

            # Diferenciando Mucocele e Rânula
            localizacao = input("👄 A lesão está localizada no assoalho da boca? (s/n): ").lower()
            if localizacao == "s":
                print("\n➡️  Diagnóstico provável: RÂNULA")
                print("     - 🐸 **Definição e Etiologia:** Fenômeno de extravasamento de muco na região de assoalho de boca devido à ruptura de um ducto da glândula sublingual. O fator etiológico é o trauma local.")
                print("     - 🔵 **Aspecto Clínico:** Aumento de volume em assoalho de boca, de coloração azulada ou translúcida, geralmente assintomático. Lesões extensas podem elevar a língua.")
                print("     - 🔬 **Como Estabelecer o Diagnóstico:** Baseado nos aspectos clínicos da lesão.")
                print("     - 🩹 **Conduta:** Remoção da lesão juntamente com a glândula ou criação cirúrgica de uma nova via de drenagem (marsupialização ou micromarsupialização).\n")
            else:
                print("\n➡️  Diagnóstico provável: MUCOCELE")
                print("     - 💧 **Definição e Etiologia:** Rompimento do ducto excretor de uma glândula salivar menor, com derramamento de mucina que se acumula no tecido conjuntivo. O principal fator etiológico é o trauma local.")
                print("     - 🔵 **Aspecto Clínico:** Aumento de volume de coloração azulada ou translúcida, assintomática, mais frequente na mucosa labial inferior. Pode ocorrer remissão e recorrência.")
                print("     - 🔬 **Como Estabelecer o Diagnóstico:** Aspecto clínico associado à história de remissão e recorrência, confirmado por exame histopatológico.")
                print("     - 🩹 **Conduta:** Remoção da lesão e das glândulas salivares menores circunvizinhas.\n")

        elif cor_liquido == "a":
            print("\n➡️  Líquido AZULADO.")

            # Diferenciando Mucocele e Rânula
            localizacao = input("👄 A lesão está localizada no assoalho da boca? (s/n): ").lower()
            if localizacao == "s":
                print("\n➡️  Diagnóstico provável: RÂNULA")
                print("     - 🐸 **Definição e Etiologia:** Fenômeno de extravasamento de muco na região de assoalho de boca devido à ruptura de um ducto da glândula sublingual. O fator etiológico é o trauma local.")
                print("     - 🔵 **Aspecto Clínico:** Aumento de volume em assoalho de boca, de coloração azulada ou translúcida, geralmente assintomático. Lesões extensas podem elevar a língua.")
                print("     - 🔬 **Como Estabelecer o Diagnóstico:** Baseado nos aspectos clínicos da lesão.")
                print("     - 🩹 **Conduta:** Remoção da lesão juntamente com a glândula ou criação cirúrgica de uma nova via de drenagem (marsupialização ou micromarsupialização).\n")
            else:
                print("\n➡️  Diagnóstico provável: MUCOCELE")
                print("     - 💧 **Definição e Etiologia:** Rompimento do ducto excretor de uma glândula salivar menor, com derramamento de mucina que se acumula no tecido conjuntivo. O principal fator etiológico é o trauma local.")
                print("     - 🔵 **Aspecto Clínico:** Aumento de volume de coloração azulada ou translúcida, assintomática, mais frequente na mucosa labial inferior. Pode ocorrer remissão e recorrência.")
                print("     - 🔬 **Como Estabelecer o Diagnóstico:** Aspecto clínico associado à história de remissão e recorrência, confirmado por exame histopatológico.")
                print("     - 🩹 **Conduta:** Remoção da lesão e das glândulas salivares menores circunvizinhas.\n")

        elif cor_liquido == "r":
            print("\n➡️  Líquido ARROXEADO/ENEGRECIDO.")
            print("   - Diagnóstico mais provável: Angina bolhosa hemorrágica")
            print("     - 🩸 **Definição e Etiologia:** Doença bucal caracterizada por bolhas e/ou vesículas contendo sangue. Etiopatogênese multifatorial, associando microtraumatismos, suscetibilidade individual e uso crônico de corticoides inalatórios. Pode estar associada a diabetes e hipertensão.")
            print("     - 🔴 **Aspecto Clínico:** Bolhas que se rompem naturalmente, resultando em ulceração que repara sem deixar cicatriz. Mais comum em adultos acima da 5ª década de vida, principalmente em palato mole e mucosa jugal.")
            print("     - 🔬 **Como Estabelecer o Diagnóstico:** Diagnóstico clínico; em casos de recorrência ou atípicos, biópsia pode ser realizada.")
            print("     - 🩹 **Conduta:** Não possui tratamento específico. Prognóstico é muito bom.\n")

        else:
            print("\n❌ Resposta inválida para coloração do líquido.")

        # Passo 3: Verificar modificação no aspecto clínico para lesão única
        print("\n➡️  HOUVE MODIFICAÇÃO NO ASPECTO CLÍNICO DA(S) LESÃO(ÕES)?")
        modificacao = input("🤔 Houve modificação no aspecto clínico (aumento/diminuição de tamanho, rompimento com liberação de muco)? (s/n): ").lower()

        if modificacao == 'n':
           print("\n➡️ SEM MODIFICAÇÂO")
           print("   - Podem aumentar e diminuir de tamanho. Eventualmente rompem, liberam muco e cicatrizam")
           print("   - Possibilidades: Mucocele ou Rânula")

    elif num_lesoes == "m":
        # Lesões Múltiplas
        print("\n➡️  Lesões MÚLTIPLAS identificadas.")
        print("   - Possibilidades: Herpes labial recorrente, Pênfigo vulgar, Penfigoide benigno de membranas mucosas")

        # Passo 3: Verificar modificação no aspecto clínico para lesões múltiplas
        print("\n➡️  HOUVE MODIFICAÇÃO NO ASPECTO CLÍNICO DA(S) LESÃO(ÕES)?")
        modificacao = input("🤔 Houve modificação no aspecto clínico (aparecimento de vesículas que se rompem e formam úlceras)? (s/n): ").lower()

        if modificacao == "s":
            print("\n➡️  COM MODIFICAÇÃO")
            print("   - Geralmente iniciam como lesões vesicobolhosas. Após rompimento, tornam-se úlceras.")

            # Diferenciando as possibilidades com base na localização e histórico
            localizacao = input("👄 As lesões estão localizadas principalmente na região de transição entre pele e vermelhão do lábio? (s/n): ").lower()
            if localizacao == "s":
                print("\n➡️  Diagnóstico provável: HERPES LABIAL RECORRENTE")
                print("     - 🦠 **Definição e Etiologia:** Reativação do vírus do herpes simples tipo I (HSV-1), desencadeada por fatores como exposição solar, imunossupressão, estresse e alterações hormonais.")
                print("     - ⚪️ **Aspecto Clínico:** Múltiplas vesículas na região de transição entre pele e vermelhão do lábio que se rompem formando úlceras e crostas. Pacientes relatam recorrência no mesmo local, precedida por prurido, ardência, dor e eritema.")
                print("     - 🔬 **Como Estabelecer o Diagnóstico:** Diagnóstico clínico baseado na história de recorrência e nas características das lesões.")
                print("     - 🩹 **Conduta:** Uso de antivirais tópicos ou sistêmicos:")
                print("         - **Uso Externo (Tópico):**")
                print("             - Aciclovir 50mg/g creme: Aplicar uma camada sobre a lesão 5 vezes ao dia, iniciando antes do rompimento das vesículas e continuar até a cicatrização.")
                print("         - **Uso Interno (Oral):**")
                print("             - Aciclovir 200mg: 1 comprimido de 2 a 5 vezes ao dia, por 5 dias.")
                print("             - Valaciclovir 500mg: 1 comprimido a cada 24h, por 5-7 dias.\n")
            else:
                print("\n➡️  Possibilidades: PÊNFIGO VULGAR ou PENFIGOIDE BENIGNO DE MEMBRANAS MUCOSAS")
                print("     - Para diferenciar Pênfigo Vulgar e Penfigoide Benigno de Membranas Mucosas, é necessária avaliação clínica detalhada e exames complementares.")
                print("     - 🧬 **Pênfigo Vulgar**")
                print("         - **Definição e Etiologia:** Doença autoimune mucocutânea crônica. Autoanticorpos (IgG) contra proteínas dos desmossomos levam à formação de bolhas intraepiteliais.")
                print("         - **Aspecto Clínico:** Bolhas que se rompem facilmente, deixando áreas ulceradas e dolorosas. Sinal de Nikolsky positivo.")
                print("         - **Como Estabelecer o Diagnóstico:** Exame clínico, histopatológico de biópsia e, em alguns casos, imunofluorescência direta.")
                print("         - **Conduta:** Corticoides tópicos e/ou sistêmicos, podendo ser associados a imunomoduladores.\n")
                print("     - 🛡️ **Penfigoide Benigno de Membranas Mucosas**")
                print("         - **Definição e Etiologia:** Doença autoimune mucocutânea vesicobolhosa. Autoanticorpos contra a membrana basal do epitélio levam à formação de bolhas.")
                print("         - **Aspecto Clínico:** Úlceras superficiais precedidas por bolhas. Sinal de Nikolsky positivo. Pode deixar cicatrizes, especialmente em lesões oculares.")
                print("         - **Como Estabelecer o Diagnóstico:** Biópsia incisional, exame histopatológico e, frequentemente, imunofluorescência direta.")
                print("         - **Conduta:** Imunossupressores e imunomoduladores tópicos e sistêmicos. Corticoides tópicos para envolvimento exclusivo de gengiva.\n")

        elif modificacao == "n":
            print("\n➡️  SEM MODIFICAÇÃO (incomum em lesões múltiplas)")
            print("   - Reavaliar o diagnóstico. Considere se as lesões são de fato múltiplas e se houve erro na avaliação da modificação.")

        else:
            print("\n❌ Resposta inválida para modificação no aspecto clínico.")

    else:
        print("\n❌ Resposta inválida para número de lesões.")

# Execução da função de diagnóstico
diagnostico_lesoes_vesicobolhosas()
# Out:
#          Texto centralizado com margens.
# 🦷 Diagnóstico de Lesões Vesicobolhosas na Mucosa Bucal 🦷
#
# 🤔 A lesão é única ou múltipla? (u/m): m
#
# ➡️  Lesões MÚLTIPLAS identificadas.
#    - Possibilidades: Herpes labial recorrente, Pênfigo vulgar, Penfigoide benigno de membranas mucosas
#
# ➡️  HOUVE MODIFICAÇÃO NO ASPECTO CLÍNICO DA(S) LESÃO(ÕES)?
# 🤔 Houve modificação no aspecto clínico (aparecimento de vesículas que se rompem e formam úlceras)? (s/n): s
#
# ➡️  COM MODIFICAÇÃO
#    - Geralmente iniciam como lesões vesicobolhosas. Após rompimento, tornam-se úlceras.
# 👄 As lesões estão localizadas principalmente na região de transição entre pele e vermelhão do lábio? (s/n): n
#
# ➡️  Possibilidades: PÊNFIGO VULGAR ou PENFIGOIDE BENIGNO DE MEMBRANAS MUCOSAS
#      - Para diferenciar Pênfigo Vulgar e Penfigoide Benigno de Membranas Mucosas, é necessária avaliação clínica detalhada e exames complementares.
#      - 🧬 **Pênfigo Vulgar**
# ...
